# %% [markdown]
# # Laboratorium 1 - analiza koszykowa
#
# ## Przygotowanie
#
#  * pobierz i wypakuj dataset: https://kaggle.com/datasets/rashikrahmanpritom/groceries-dataset-for-market-basket-analysismba?resource=download&select=basket.csv
#    * alternatywnie, pobierz plik `basket.csv` z Teamsów
#  * [opcjonalnie] Utwórz wirtualne środowisko
#  `python3 -m venv ./recsyslab1`
#  * zainstaluj potrzebne biblioteki:
#  `pip install more-itertools`

# %% [markdown]
# ## Część 1. - przygotowanie danych

# %%
# importujemy wszystkie potrzebne pakiety
from more_itertools import powerset

# %%
# definiujemy stale

PATH = './basket.csv'
EPSILON = 0.000001

# %%
# wczytujemy dane o koszykach

def read_baskets(path: str) -> list[tuple[str]]:
    with open(path) as f:
        raw = f.read()
    baskets = [set([y.lower() for y in x.split(',') if y]) for x in raw.split('\n')[1:] if x]
    return baskets

def unique_products(baskets: list[tuple[str]]) -> list[str]:
    products = set()
    for basket in baskets:
        products.update(basket)
    return sorted(list(products))

baskets = read_baskets(PATH)
products = unique_products(baskets)

# %% [markdown]
# ## Część 2. - obliczanie wskaźników

# %%
# obliczamy strukture danych (np. slownik albo graf) przechowujaca wszystkie interesujace wartosci `support`

def get_supports(baskets: list[tuple[str]], all_products: list[str], epsilon: float):
    supports = {}
    
    def add_layer(current_basket: tuple[str], considered_baskets):
        for product in all_products:
            if product in current_basket:
                continue
            new_basket = current_basket + (product, )
            if tuple(sorted(new_basket)) in supports:
                continue
            count = 0
            new_considered_baskets = []
            for basket in considered_baskets:
                if set(new_basket) <= set(basket):
                    count += 1
                    new_considered_baskets.append(basket)
            support = count / len(baskets)
            if support >= epsilon:
                supports[tuple(sorted(new_basket))] = support
                add_layer(new_basket, new_considered_baskets)

    add_layer((), baskets)

    return supports
        

    
supports = get_supports(baskets, products, EPSILON)
supports
# Out:
# {('abrasive cleaner',): 0.0014702933903628951,
#  ('abrasive cleaner', 'beef'): 0.00013366303548753594,
#  ('abrasive cleaner', 'beef', 'frozen vegetables'): 6.683151774376797e-05,
#  ('abrasive cleaner',
#   'beef',
#   'frozen vegetables',
#   'uht-milk'): 6.683151774376797e-05,
#  ('abrasive cleaner', 'beef', 'pasta'): 6.683151774376797e-05,
#  ('abrasive cleaner', 'beef', 'pasta', 'pork'): 6.683151774376797e-05,
#  ('abrasive cleaner',
#   'beef',
#   'pasta',
#   'pork',
#   'salty snack'): 6.683151774376797e-05,
#  ('abrasive cleaner',
#   'beef',
#   'pasta',
#   'pork',
#   'salty snack',
#   'shopping bags'): 6.683151774376797e-05,
#  ('abrasive cleaner',
#   'beef',
#   'pasta',
#   'pork',
#   'shopping bags'): 6.683151774376797e-05,
#  ('abrasive cleaner', 'beef', 'pasta', 'salty snack'): 6.683151774376797e-05,
#  ('abrasive cleaner',
#   'beef',
#   'pasta',
#   'salty snack',
#   'shopping bags'): 6.683151774376797e-05,
#  ('abrasive cleaner', 'beef', 'pasta', 'shopping bags'): 6.683151774376797e-05,
#  ('abrasive cleaner', 'beef', 'pork'): 6.683151774376797e-05,
#  ('abrasive cleaner', 'beef', 'pork', 'salty snack'): 6.683151774376797e-05,
#  ('abrasive cleaner',
#   'beef',
#   'pork',
#   'salty snack',
#   'shopping bags'): 6.683151774376797e-05,
#  ('abrasive cleaner', 'beef', 'pork', 'shopping bags'): 6.683151774376797e-05,
#  ('abrasive cleaner', 'beef', 'salty snack'): 6.683151774376797e-05,
#  ('abrasive cleaner',
#   'beef',
#   'salty snack',
#   'shopping bags'): 6.683151774376797e-05,
#  ('abrasive cleaner', 'beef', 'shopping bags'): 6.683151774376797e-05,
#  ('abrasive cleaner', 'beef', 'uht-milk'): 6.683151774376797e-05,
#  ('abrasive cleaner', 'bottled beer'): 6.683151774376797e-05,
#  ('abrasive cleaner',
#   'bottled beer',
#   'other vegetables'): 6.683151774376797e-05,
#  ('abrasive cleaner', 'bottled water'): 6.683151774376797e-05,
#  ('abrasive cleaner', 'bottled water', 'meat'): 6.683151774376797e-05,
#  ('abrasive cleaner', 'canned beer'): 6.683151774376797e-05,
#  ('abrasive cleaner', 'canned beer', 'turkey'): 6.683151774376797e-05,
#  ('abrasive cleaner', 'chicken'): 6.683151774376797e-05,
#  ('abrasive cleaner', 'citrus fruit'): 6.683151774376797e-05,
#  ('abrasive cleaner',
#   'citrus fruit',
#   'long life bakery product'): 6.683151774376797e-05,
#  ('abrasive cleaner',
#   'citrus fruit',
#   'long life bakery product',
#   'whole milk'): 6.683151774376797e-05,
#  ('abrasive cleaner', 'citrus fruit', 'whole milk'): 6.683151774376797e-05,
#  ('abrasive cleaner', 'curd'): 6.683151774376797e-05,
#  ('abrasive cleaner', 'curd', 'other vegetables'): 6.683151774376797e-05,
#  ('abrasive cleaner', 'fish'): 6.683151774376797e-05,
#  ('abrasive cleaner', 'fish', 'margarine'): 6.683151774376797e-05,
#  ('abrasive cleaner', 'fish', 'margarine', 'meat'): 6.683151774376797e-05,
#  ('abrasive cleaner',
#   'fish',
#   'margarine',
#   'meat',
#   'meat spreads'): 6.683151774376797e-05,
#  ('abrasive cleaner',
#   'fish',
#   'margarine',
#   'meat spreads'): 6.683151774376797e-05,
#  ('abrasive cleaner', 'fish', 'meat'): 6.683151774376797e-05,
#  ('abrasive cleaner', 'fish', 'meat', 'meat spreads'): 6.683151774376797e-05,
#  ('abrasive cleaner', 'fish', 'meat spreads'): 6.683151774376797e-05,
#  ('abrasive cleaner', 'frankfurter'): 6.683151774376797e-05,
#  ('abrasive cleaner',
#   'frankfurter',
#   'frozen potato products'): 6.683151774376797e-05,
#  ('abrasive cleaner',
#   'frankfurter',
#   'frozen potato products',
#   'newspapers'): 6.683151774376797e-05,
#  ('abrasive cleaner',
#   'frankfurter',
#   'frozen potato products',
#   'newspapers',
#   'softener'): 6.683151774376797e-05,
#  ('abrasive cleaner',
#   'frankfurter',
#   'frozen potato products',
#   'softener'): 6.683151774376797e-05,
#  ('abrasive cleaner', 'frankfurter', 'newspapers'): 6.683151774376797e-05,
#  ('abrasive cleaner',
#   'frankfurter',
#   'newspapers',
#   'softener'): 6.683151774376797e-05,
#  ('abrasive cleaner', 'frankfurter', 'softener'): 6.683151774376797e-05,
#  ('abrasive cleaner', 'frozen meals'): 0.00013366303548753594,
#  ('abrasive cleaner', 'frozen meals', 'yogurt'): 6.683151774376797e-05,
#  ('abrasive cleaner', 'frozen potato products'): 6.683151774376797e-05,
#  ('abrasive cleaner',
#   'frozen potato products',
#   'newspapers'): 6.683151774376797e-05,
#  ('abrasive cleaner',
#   'frozen potato products',
#   'newspapers',
#   'softener'): 6.683151774376797e-05,
#  ('abrasive cleaner',
#   'frozen potato products',
#   'softener'): 6.683151774376797e-05,
#  ('abrasive cleaner', 'frozen vegetables'): 0.00013366303548753594,
#  ('abrasive cleaner', 'frozen vegetables', 'pip fruit'): 6.683151774376797e-05,
#  ('abrasive cleaner', 'frozen vegetables', 'uht-milk'): 6.683151774376797e-05,
#  ('abrasive cleaner', 'long life bakery product'): 6.683151774376797e-05,
#  ('abrasive cleaner',
#   'long life bakery product',
#   'whole milk'): 6.683151774376797e-05,
#  ('abrasive cleaner', 'margarine'): 6.683151774376797e-05,
#  ('abrasive cleaner', 'margarine', 'meat'): 6.683151774376797e-05,
#  ('abrasive cleaner',
#   'margarine',
#   'meat',
#   'meat spreads'): 6.683151774376797e-05,
#  ('abrasive cleaner', 'margarine', 'meat spreads'): 6.683151774376797e-05,
#  ('abrasive cleaner', 'meat'): 0.00013366303548753594,
#  ('abrasive cleaner', 'meat', 'meat spreads'): 6.683151774376797e-05,
#  ('abrasive cleaner', 'meat spreads'): 6.683151774376797e-05,
#  ('abrasive cleaner', 'napkins'): 6.683151774376797e-05,
#  ('abrasive cleaner',
#   'napkins',
#   'packaged fruit/vegetables'): 6.683151774376797e-05,
#  ('abrasive cleaner',
#   'napkins',
#   'packaged fruit/vegetables',
#   'whole milk'): 6.683151774376797e-05,
#  ('abrasive cleaner', 'napkins', 'whole milk'): 6.683151774376797e-05,
#  ('abrasive cleaner', 'newspapers'): 6.683151774376797e-05,
#  ('abrasive cleaner', 'newspapers', 'softener'): 6.683151774376797e-05,
#  ('abrasive cleaner', 'onions'): 6.683151774376797e-05,
#  ('abrasive cleaner', 'other vegetables'): 0.00020049455323130388,
#  ('abrasive cleaner', 'packaged fruit/vegetables'): 6.683151774376797e-05,
#  ('abrasive cleaner',
#   'packaged fruit/vegetables',
#   'whole milk'): 6.683151774376797e-05,
#  ('abrasive cleaner', 'pasta'): 6.683151774376797e-05,
#  ('abrasive cleaner', 'pasta', 'pork'): 6.683151774376797e-05,
#  ('abrasive cleaner', 'pasta', 'pork', 'salty snack'): 6.683151774376797e-05,
#  ('abrasive cleaner',
#   'pasta',
#   'pork',
#   'salty snack',
#   'shopping bags'): 6.683151774376797e-05,
#  ('abrasive cleaner', 'pasta', 'pork', 'shopping bags'): 6.683151774376797e-05,
#  ('abrasive cleaner', 'pasta', 'salty snack'): 6.683151774376797e-05,
#  ('abrasive cleaner',
#   'pasta',
#   'salty snack',
#   'shopping bags'): 6.683151774376797e-05,
#  ('abrasive cleaner', 'pasta', 'shopping bags'): 6.683151774376797e-05,
#  ('abrasive cleaner', 'pip fruit'): 0.00013366303548753594,
#  ('abrasive cleaner', 'pork'): 6.683151774376797e-05,
#  ('abrasive cleaner', 'pork', 'salty snack'): 6.683151774376797e-05,
#  ('abrasive cleaner',
#   'pork',
#   'salty snack',
#   'shopping bags'): 6.683151774376797e-05,
#  ('abrasive cleaner', 'pork', 'shopping bags'): 6.683151774376797e-05,
#  ('abrasive cleaner', 'red/blush wine'): 6.683151774376797e-05,
#  ('abrasive cleaner',
#   'red/blush wine',
#   'specialty cheese'): 6.683151774376797e-05,
#  ('abrasive cleaner',
#   'red/blush wine',
#   'specialty cheese',
#   'whipped/sour cream'): 6.683151774376797e-05,
#  ('abrasive cleaner',
#   'red/blush wine',
#   'whipped/sour cream'): 6.683151774376797e-05,
#  ('abrasive cleaner', 'rolls/buns'): 6.683151774376797e-05,
#  ('abrasive cleaner', 'root vegetables'): 6.683151774376797e-05,
#  ('abrasive cleaner', 'root vegetables', 'soda'): 6.683151774376797e-05,
#  ('abrasive cleaner',
#   'root vegetables',
#   'soda',
#   'whipped/sour cream'): 6.683151774376797e-05,
#  ('abrasive cleaner',
#   'root vegetables',
#   'soda',
#   'whipped/sour cream',
#   'white wine'): 6.683151774376797e-05,
#  ('abrasive cleaner',
#   'root vegetables',
#   'soda',
#   'white wine'): 6.683151774376797e-05,
#  ('abrasive cleaner',
#   'root vegetables',
#   'whipped/sour cream'): 6.683151774376797e-05,
#  ('abrasive cleaner',
#   'root vegetables',
#   'whipped/sour cream',
#   'white wine'): 6.683151774376797e-05,
#  ('abrasive cleaner', 'root vegetables', 'white wine'): 6.683151774376797e-05,
#  ('abrasive cleaner', 'salty snack'): 6.683151774376797e-05,
#  ('abrasive cleaner', 'salty snack', 'shopping bags'): 6.683151774376797e-05,
#  ('abrasive cleaner', 'seasonal products'): 6.683151774376797e-05,
#  ('abrasive cleaner', 'seasonal products', 'soda'): 6.683151774376797e-05,
#  ('abrasive cleaner', 'shopping bags'): 6.683151774376797e-05,
#  ('abrasive cleaner', 'soda'): 0.00013366303548753594,
#  ('abrasive cleaner', 'soda', 'whipped/sour cream'): 6.683151774376797e-05,
#  ('abrasive cleaner',
#   'soda',
#   'whipped/sour cream',
#   'white wine'): 6.683151774376797e-05,
#  ('abrasive cleaner', 'soda', 'white wine'): 6.683151774376797e-05,
#  ('abrasive cleaner', 'softener'): 6.683151774376797e-05,
#  ('abrasive cleaner', 'specialty cheese'): 6.683151774376797e-05,
#  ('abrasive cleaner',
#   'specialty cheese',
#   'whipped/sour cream'): 6.683151774376797e-05,
#  ('abrasive cleaner', 'turkey'): 6.683151774376797e-05,
#  ('abrasive cleaner', 'uht-milk'): 6.683151774376797e-05,
#  ('abrasive cleaner', 'whipped/sour cream'): 0.00013366303548753594,
#  ('abrasive cleaner',
#   'whipped/sour cream',
#   'white wine'): 6.683151774376797e-05,
#  ('abrasive cleaner', 'white wine'): 6.683151774376797e-05,
#  ('abrasive cleaner', 'whole milk'): 0.00020049455323130388,
#  ('abrasive cleaner', 'whole milk', 'yogurt'): 6.683151774376797e-05,
#  ('abrasive cleaner', 'yogurt'): 0.00013366303548753594,
#  ('artif. sweetener',): 0.0019381140145692708,
#  ('artif. sweetener', 'baby cosmetics'): 6.683151774376797e-05,
#  ('artif. sweetener', 'baby cosmetics', 'beef'): 6.683151774376797e-05,
#  ('artif. sweetener',
#   'baby cosmetics',
#   'beef',
#   'domestic eggs'): 6.683151774376797e-05,
#  ('artif. sweetener',
#   'baby cosmetics',
#   'beef',
#   'domestic eggs',
#   'frankfurter'): 6.683151774376797e-05,
#  ('artif. sweetener',
#   'baby cosmetics',
#   'beef',
#   'domestic eggs',
#   'frankfurter',
#   'ham'): 6.683151774376797e-05,
#  ('artif. sweetener',
#   'baby cosmetics',
#   'beef',
#   'domestic eggs',
#   'frankfurter',
#   'ham',
#   'margarine'): 6.683151774376797e-05,
#  ('artif. sweetener',
#   'baby cosmetics',
#   'beef',
#   'domestic eggs',
#   'frankfurter',
#   'ham',
#   'margarine',
#   'other vegetables'): 6.683151774376797e-05,
#  ('artif. sweetener',
#   'baby cosmetics',
#   'beef',
#   'domestic eggs',
#   'frankfurter',
#   'ham',
#   'other vegetables'): 6.683151774376797e-05,
#  ('artif. sweetener',
#   'baby cosmetics',
#   'beef',
#   'domestic eggs',
#   'frankfurter',
#   'margarine'): 6.683151774376797e-05,
#  ('artif. sweetener',
#   'baby cosmetics',
#   'beef',
#   'domestic eggs',
#   'frankfurter',
#   'margarine',
#   'other vegetables'): 6.683151774376797e-05,
#  ('artif. sweetener',
#   'baby cosmetics',
#   'beef',
#   'domestic eggs',
#   'frankfurter',
#   'other vegetables'): 6.683151774376797e-05,
#  ('artif. sweetener',
#   'baby cosmetics',
#   'beef',
#   'domestic eggs',
#   'ham'): 6.683151774376797e-05,
#  ('artif. sweetener',
#   'baby cosmetics',
#   'beef',
#   'domestic eggs',
#   'ham',
#   'margarine'): 6.683151774376797e-05,
#  ('artif. sweetener',
#   'baby cosmetics',
#   'beef',
#   'domestic eggs',
#   'ham',
#   'margarine',
#   'other vegetables'): 6.683151774376797e-05,
#  ('artif. sweetener',
#   'baby cosmetics',
#   'beef',
#   'domestic eggs',
#   'ham',
#   'other vegetables'): 6.683151774376797e-05,
#  ('artif. sweetener',
#   'baby cosmetics',
#   'beef',
#   'domestic eggs',
#   'margarine'): 6.683151774376797e-05,
#  ('artif. sweetener',
#   'baby cosmetics',
#   'beef',
#   'domestic eggs',
#   'margarine',
#   'other vegetables'): 6.683151774376797e-05,
#  ('artif. sweetener',
#   'baby cosmetics',
#   'beef',
#   'domestic eggs',
#   'other vegetables'): 6.683151774376797e-05,
#  ('artif. sweetener',
#   'baby cosmetics',
#   'beef',
#   'frankfurter'): 6.683151774376797e-05,
#  ('artif. sweetener',
#   'baby cosmetics',
#   'beef',
#   'frankfurter',
#   'ham'): 6.683151774376797e-05,
#  ('artif. sweetener',
#   'baby cosmetics',
#   'beef',
#   'frankfurter',
#   'ham',
#   'margarine'): 6.683151774376797e-05,
#  ('artif. sweetener',
#   'baby cosmetics',
#   'beef',
#   'frankfurter',
#   'ham',
#   'margarine',
#   'other vegetables'): 6.683151774376797e-05,
#  ('artif. sweetener',
#   'baby cosmetics',
#   'beef',
#   'frankfurter',
#   'ham',
#   'other vegetables'): 6.683151774376797e-05,
#  ('artif. sweetener',
#   'baby cosmetics',
#   'beef',
#   'frankfurter',
#   'margarine'): 6.683151774376797e-05,
#  ('artif. sweetener',
#   'baby cosmetics',
#   'beef',
#   'frankfurter',
#   'margarine',
#   'other vegetables'): 6.683151774376797e-05,
#  ('artif. sweetener',
#   'baby cosmetics',
#   'beef',
#   'frankfurter',
#   'other vegetables'): 6.683151774376797e-05,
#  ('artif. sweetener', 'baby cosmetics', 'beef', 'ham'): 6.683151774376797e-05,
#  ('artif. sweetener',
#   'baby cosmetics',
#   'beef',
#   'ham',
#   'margarine'): 6.683151774376797e-05,
#  ('artif. sweetener',
#   'baby cosmetics',
#   'beef',
#   'ham',
#   'margarine',
#   'other vegetables'): 6.683151774376797e-05,
#  ('artif. sweetener',
#   'baby cosmetics',
#   'beef',
#   'ham',
#   'other vegetables'): 6.683151774376797e-05,
#  ('artif. sweetener',
#   'baby cosmetics',
#   'beef',
#   'margarine'): 6.683151774376797e-05,
#  ('artif. sweetener',
#   'baby cosmetics',
#   'beef',
#   'margarine',
#   'other vegetables'): 6.683151774376797e-05,
#  ('artif. sweetener',
#   'baby cosmetics',
#   'beef',
#   'other vegetables'): 6.683151774376797e-05,
#  ('artif. sweetener',
#   'baby cosmetics',
#   'domestic eggs'): 6.683151774376797e-05,
#  ('artif. sweetener',
#   'baby cosmetics',
#   'domestic eggs',
#   'frankfurter'): 6.683151774376797e-05,
#  ('artif. sweetener',
#   'baby cosmetics',
#   'domestic eggs',
#   'frankfurter',
#   'ham'): 6.683151774376797e-05,
#  ('artif. sweetener',
#   'baby cosmetics',
#   'domestic eggs',
#   'frankfurter',
#   'ham',
#   'margarine'): 6.683151774376797e-05,
#  ('artif. sweetener',
#   'baby cosmetics',
#   'domestic eggs',
#   'frankfurter',
#   'ham',
#   'margarine',
#   'other vegetables'): 6.683151774376797e-05,
#  ('artif. sweetener',
#   'baby cosmetics',
#   'domestic eggs',
#   'frankfurter',
#   'ham',
#   'other vegetables'): 6.683151774376797e-05,
#  ('artif. sweetener',
#   'baby cosmetics',
#   'domestic eggs',
#   'frankfurter',
#   'margarine'): 6.683151774376797e-05,
#  ('artif. sweetener',
#   'baby cosmetics',
#   'domestic eggs',
#   'frankfurter',
#   'margarine',
#   'other vegetables'): 6.683151774376797e-05,
#  ('artif. sweetener',
#   'baby cosmetics',
#   'domestic eggs',
#   'frankfurter',
#   'other vegetables'): 6.683151774376797e-05,
#  ('artif. sweetener',
#   'baby cosmetics',
#   'domestic eggs',
#   'ham'): 6.683151774376797e-05,
#  ('artif. sweetener',
#   'baby cosmetics',
#   'domestic eggs',
#   'ham',
#   'margarine'): 6.683151774376797e-05,
#  ('artif. sweetener',
#   'baby cosmetics',
#   'domestic eggs',
#   'ham',
#   'margarine',
#   'other vegetables'): 6.683151774376797e-05,
#  ('artif. sweetener',
#   'baby cosmetics',
#   'domestic eggs',
#   'ham',
#   'other vegetables'): 6.683151774376797e-05,
#  ('artif. sweetener',
#   'baby cosmetics',
#   'domestic eggs',
#   'margarine'): 6.683151774376797e-05,
#  ('artif. sweetener',
#   'baby cosmetics',
#   'domestic eggs',
#   'margarine',
#   'other vegetables'): 6.683151774376797e-05,
#  ('artif. sweetener',
#   'baby cosmetics',
#   'domestic eggs',
#   'other vegetables'): 6.683151774376797e-05,
#  ('artif. sweetener', 'baby cosmetics', 'frankfurter'): 6.683151774376797e-05,
#  ('artif. sweetener',
#   'baby cosmetics',
#   'frankfurter',
#   'ham'): 6.683151774376797e-05,
#  ('artif. sweetener',
#   'baby cosmetics',
#   'frankfurter',
#   'ham',
#   'margarine'): 6.683151774376797e-05,
#  ('artif. sweetener',
#   'baby cosmetics',
#   'frankfurter',
#   'ham',
#   'margarine',
#   'other vegetables'): 6.683151774376797e-05,
#  ('artif. sweetener',
#   'baby cosmetics',
#   'frankfurter',
#   'ham',
#   'other vegetables'): 6.683151774376797e-05,
#  ('artif. sweetener',
#   'baby cosmetics',
#   'frankfurter',
#   'margarine'): 6.683151774376797e-05,
#  ('artif. sweetener',
#   'baby cosmetics',
#   'frankfurter',
#   'margarine',
#   'other vegetables'): 6.683151774376797e-05,
#  ('artif. sweetener',
#   'baby cosmetics',
#   'frankfurter',
#   'other vegetables'): 6.683151774376797e-05,
#  ('artif. sweetener', 'baby cosmetics', 'ham'): 6.683151774376797e-05,
#  ('artif. sweetener',
#   'baby cosmetics',
#   'ham',
#   'margarine'): 6.683151774376797e-05,
#  ('artif. sweetener',
#   'baby cosmetics',
#   'ham',
#   'margarine',
#   'other vegetables'): 6.683151774376797e-05,
#  ('artif. sweetener',
#   'baby cosmetics',
#   'ham',
#   'other vegetables'): 6.683151774376797e-05,
#  ('artif. sweetener', 'baby cosmetics', 'margarine'): 6.683151774376797e-05,
#  ('artif. sweetener',
#   'baby cosmetics',
#   'margarine',
#   'other vegetables'): 6.683151774376797e-05,
#  ('artif. sweetener',
#   'baby cosmetics',
#   'other vegetables'): 6.683151774376797e-05,
#  ('artif. sweetener', 'beef'): 6.683151774376797e-05,
#  ('artif. sweetener', 'beef', 'domestic eggs'): 6.683151774376797e-05,
#  ('artif. sweetener',
#   'beef',
#   'domestic eggs',
#   'frankfurter'): 6.683151774376797e-05,
#  ('artif. sweetener',
#   'beef',
#   'domestic eggs',
#   'frankfurter',
#   'ham'): 6.683151774376797e-05,
#  ('artif. sweetener',
#   'beef',
#   'domestic eggs',
#   'frankfurter',
#   'ham',
#   'margarine'): 6.683151774376797e-05,
#  ('artif. sweetener',
#   'beef',
#   'domestic eggs',
#   'frankfurter',
#   'ham',
#   'margarine',
#   'other vegetables'): 6.683151774376797e-05,
#  ('artif. sweetener',
#   'beef',
#   'domestic eggs',
#   'frankfurter',
#   'ham',
#   'other vegetables'): 6.683151774376797e-05,
#  ('artif. sweetener',
#   'beef',
#   'domestic eggs',
#   'frankfurter',
#   'margarine'): 6.683151774376797e-05,
#  ('artif. sweetener',
#   'beef',
#   'domestic eggs',
#   'frankfurter',
#   'margarine',
#   'other vegetables'): 6.683151774376797e-05,
#  ('artif. sweetener',
#   'beef',
#   'domestic eggs',
#   'frankfurter',
#   'other vegetables'): 6.683151774376797e-05,
#  ('artif. sweetener', 'beef', 'domestic eggs', 'ham'): 6.683151774376797e-05,
#  ('artif. sweetener',
#   'beef',
#   'domestic eggs',
#   'ham',
#   'margarine'): 6.683151774376797e-05,
#  ('artif. sweetener',
#   'beef',
#   'domestic eggs',
#   'ham',
#   'margarine',
#   'other vegetables'): 6.683151774376797e-05,
#  ('artif. sweetener',
#   'beef',
#   'domestic eggs',
#   'ham',
#   'other vegetables'): 6.683151774376797e-05,
#  ('artif. sweetener',
#   'beef',
#   'domestic eggs',
#   'margarine'): 6.683151774376797e-05,
#  ('artif. sweetener',
#   'beef',
#   'domestic eggs',
#   'margarine',
#   'other vegetables'): 6.683151774376797e-05,
#  ('artif. sweetener',
#   'beef',
#   'domestic eggs',
#   'other vegetables'): 6.683151774376797e-05,
#  ('artif. sweetener', 'beef', 'frankfurter'): 6.683151774376797e-05,
#  ('artif. sweetener', 'beef', 'frankfurter', 'ham'): 6.683151774376797e-05,
#  ('artif. sweetener',
#   'beef',
#   'frankfurter',
#   'ham',
#   'margarine'): 6.683151774376797e-05,
#  ('artif. sweetener',
#   'beef',
#   'frankfurter',
#   'ham',
#   'margarine',
#   'other vegetables'): 6.683151774376797e-05,
#  ('artif. sweetener',
#   'beef',
#   'frankfurter',
#   'ham',
#   'other vegetables'): 6.683151774376797e-05,
#  ('artif. sweetener',
#   'beef',
#   'frankfurter',
#   'margarine'): 6.683151774376797e-05,
#  ('artif. sweetener',
#   'beef',
#   'frankfurter',
#   'margarine',
#   'other vegetables'): 6.683151774376797e-05,
#  ('artif. sweetener',
#   'beef',
#   'frankfurter',
#   'other vegetables'): 6.683151774376797e-05,
#  ('artif. sweetener', 'beef', 'ham'): 6.683151774376797e-05,
#  ('artif. sweetener', 'beef', 'ham', 'margarine'): 6.683151774376797e-05,
#  ('artif. sweetener',
#   'beef',
#   'ham',
#   'margarine',
#   'other vegetables'): 6.683151774376797e-05,
#  ('artif. sweetener',
#   'beef',
#   'ham',
#   'other vegetables'): 6.683151774376797e-05,
#  ('artif. sweetener', 'beef', 'margarine'): 6.683151774376797e-05,
#  ('artif. sweetener',
#   'beef',
#   'margarine',
#   'other vegetables'): 6.683151774376797e-05,
#  ('artif. sweetener', 'beef', 'other vegetables'): 6.683151774376797e-05,
#  ('artif. sweetener', 'bottled beer'): 6.683151774376797e-05,
#  ('artif. sweetener', 'bottled beer', 'butter'): 6.683151774376797e-05,
#  ('artif. sweetener',
#   'bottled beer',
#   'butter',
#   'candles'): 6.683151774376797e-05,
#  ('artif. sweetener',
#   'bottled beer',
#   'butter',
#   'candles',
#   'chewing gum'): 6.683151774376797e-05,
#  ('artif. sweetener',
#   'bottled beer',
#   'butter',
#   'candles',
#   'chewing gum',
#   'sausage'): 6.683151774376797e-05,
#  ('artif. sweetener',
#   'bottled beer',
#   'butter',
#   'candles',
#   'chewing gum',
#   'sausage',
#   'uht-milk'): 6.683151774376797e-05,
#  ('artif. sweetener',
#   'bottled beer',
#   'butter',
#   'candles',
#   'chewing gum',
#   'uht-milk'): 6.683151774376797e-05,
#  ('artif. sweetener',
#   'bottled beer',
#   'butter',
#   'candles',
#   'sausage'): 6.683151774376797e-05,
#  ('artif. sweetener',
#   'bottled beer',
#   'butter',
#   'candles',
#   'sausage',
#   'uht-milk'): 6.683151774376797e-05,
#  ('artif. sweetener',
#   'bottled beer',
#   'butter',
#   'candles',
#   'uht-milk'): 6.683151774376797e-05,
#  ('artif. sweetener',
#   'bottled beer',
#   'butter',
#   'chewing gum'): 6.683151774376797e-05,
#  ('artif. sweetener',
#   'bottled beer',
#   'butter',
#   'chewing gum',
#   'sausage'): 6.683151774376797e-05,
#  ('artif. sweetener',
#   'bottled beer',
#   'butter',
#   'chewing gum',
#   'sausage',
#   'uht-milk'): 6.683151774376797e-05,
#  ('artif. sweetener',
#   'bottled beer',
#   'butter',
#   'chewing gum',
#   'uht-milk'): 6.683151774376797e-05,
#  ('artif. sweetener',
#   'bottled beer',
#   'butter',
#   'sausage'): 6.683151774376797e-05,
#  ('artif. sweetener',
#   'bottled beer',
#   'butter',
#   'sausage',
#   'uht-milk'): 6.683151774376797e-05,
#  ('artif. sweetener',
#   'bottled beer',
#   'butter',
#   'uht-milk'): 6.683151774376797e-05,
#  ('artif. sweetener', 'bottled beer', 'candles'): 6.683151774376797e-05,
#  ('artif. sweetener',
#   'bottled beer',
#   'candles',
#   'chewing gum'): 6.683151774376797e-05,
#  ('artif. sweetener',
#   'bottled beer',
#   'candles',
#   'chewing gum',
#   'sausage'): 6.683151774376797e-05,
#  ('artif. sweetener',
#   'bottled beer',
#   'candles',
#   'chewing gum',
#   'sausage',
#   'uht-milk'): 6.683151774376797e-05,
#  ('artif. sweetener',
#   'bottled beer',
#   'candles',
#   'chewing gum',
#   'uht-milk'): 6.683151774376797e-05,
#  ('artif. sweetener',
#   'bottled beer',
#   'candles',
#   'sausage'): 6.683151774376797e-05,
#  ('artif. sweetener',
#   'bottled beer',
#   'candles',
#   'sausage',
#   'uht-milk'): 6.683151774376797e-05,
#  ('artif. sweetener',
#   'bottled beer',
#   'candles',
#   'uht-milk'): 6.683151774376797e-05,
#  ('artif. sweetener', 'bottled beer', 'chewing gum'): 6.683151774376797e-05,
#  ('artif. sweetener',
#   'bottled beer',
#   'chewing gum',
#   'sausage'): 6.683151774376797e-05,
#  ('artif. sweetener',
#   'bottled beer',
#   'chewing gum',
#   'sausage',
#   'uht-milk'): 6.683151774376797e-05,
#  ('artif. sweetener',
#   'bottled beer',
#   'chewing gum',
#   'uht-milk'): 6.683151774376797e-05,
#  ('artif. sweetener', 'bottled beer', 'sausage'): 6.683151774376797e-05,
#  ('artif. sweetener',
#   'bottled beer',
#   'sausage',
#   'uht-milk'): 6.683151774376797e-05,
#  ('artif. sweetener', 'bottled beer', 'uht-milk'): 6.683151774376797e-05,
#  ('artif. sweetener', 'bottled water'): 0.00013366303548753594,
#  ('artif. sweetener', 'bottled water', 'butter'): 6.683151774376797e-05,
#  ('artif. sweetener',
#   'bottled water',
#   'butter',
#   'butter milk'): 6.683151774376797e-05,
#  ('artif. sweetener',
#   'bottled water',
#   'butter',
#   'butter milk',
#   'soda'): 6.683151774376797e-05,
#  ('artif. sweetener',
#   'bottled water',
#   'butter',
#   'soda'): 6.683151774376797e-05,
#  ('artif. sweetener', 'bottled water', 'butter milk'): 6.683151774376797e-05,
#  ('artif. sweetener',
#   'bottled water',
#   'butter milk',
#   'soda'): 6.683151774376797e-05,
#  ('artif. sweetener', 'bottled water', 'cocoa drinks'): 6.683151774376797e-05,
#  ('artif. sweetener',
#   'bottled water',
#   'cocoa drinks',
#   'soda'): 6.683151774376797e-05,
#  ('artif. sweetener', 'bottled water', 'soda'): 0.00013366303548753594,
#  ('artif. sweetener', 'butter'): 0.00013366303548753594,
#  ('artif. sweetener', 'butter', 'butter milk'): 6.683151774376797e-05,
#  ('artif. sweetener', 'butter', 'butter milk', 'soda'): 6.683151774376797e-05,
#  ('artif. sweetener', 'butter', 'candles'): 6.683151774376797e-05,
#  ('artif. sweetener',
#   'butter',
#   'candles',
#   'chewing gum'): 6.683151774376797e-05,
#  ('artif. sweetener',
#   'butter',
#   'candles',
#   'chewing gum',
#   'sausage'): 6.683151774376797e-05,
#  ('artif. sweetener',
#   'butter',
#   'candles',
#   'chewing gum',
#   'sausage',
#   'uht-milk'): 6.683151774376797e-05,
#  ('artif. sweetener',
#   'butter',
#   'candles',
#   'chewing gum',
#   'uht-milk'): 6.683151774376797e-05,
#  ('artif. sweetener', 'butter', 'candles', 'sausage'): 6.683151774376797e-05,
#  ('artif. sweetener',
#   'butter',
#   'candles',
#   'sausage',
#   'uht-milk'): 6.683151774376797e-05,
#  ('artif. sweetener', 'butter', 'candles', 'uht-milk'): 6.683151774376797e-05,
#  ('artif. sweetener', 'butter', 'chewing gum'): 6.683151774376797e-05,
#  ('artif. sweetener',
#   'butter',
#   'chewing gum',
#   'sausage'): 6.683151774376797e-05,
#  ('artif. sweetener',
#   'butter',
#   'chewing gum',
#   'sausage',
#   'uht-milk'): 6.683151774376797e-05,
#  ('artif. sweetener',
#   'butter',
#   'chewing gum',
#   'uht-milk'): 6.683151774376797e-05,
#  ('artif. sweetener', 'butter', 'sausage'): 6.683151774376797e-05,
#  ('artif. sweetener', 'butter', 'sausage', 'uht-milk'): 6.683151774376797e-05,
#  ('artif. sweetener', 'butter', 'soda'): 6.683151774376797e-05,
#  ('artif. sweetener', 'butter', 'uht-milk'): 6.683151774376797e-05,
#  ('artif. sweetener', 'butter milk'): 6.683151774376797e-05,
#  ('artif. sweetener', 'butter milk', 'soda'): 6.683151774376797e-05,
#  ('artif. sweetener', 'candles'): 6.683151774376797e-05,
#  ('artif. sweetener', 'candles', 'chewing gum'): 6.683151774376797e-05,
#  ('artif. sweetener',
#   'candles',
#   'chewing gum',
#   'sausage'): 6.683151774376797e-05,
#  ('artif. sweetener',
#   'candles',
#   'chewing gum',
#   'sausage',
#   'uht-milk'): 6.683151774376797e-05,
#  ('artif. sweetener',
#   'candles',
#   'chewing gum',
#   'uht-milk'): 6.683151774376797e-05,
#  ('artif. sweetener', 'candles', 'sausage'): 6.683151774376797e-05,
#  ('artif. sweetener', 'candles', 'sausage', 'uht-milk'): 6.683151774376797e-05,
#  ('artif. sweetener', 'candles', 'uht-milk'): 6.683151774376797e-05,
#  ('artif. sweetener', 'canned beer'): 6.683151774376797e-05,
#  ('artif. sweetener', 'canned beer', 'rolls/buns'): 6.683151774376797e-05,
#  ('artif. sweetener',
#   'canned beer',
#   'rolls/buns',
#   'soda'): 6.683151774376797e-05,
#  ('artif. sweetener', 'canned beer', 'soda'): 6.683151774376797e-05,
#  ('artif. sweetener', 'canned fish'): 6.683151774376797e-05,
#  ('artif. sweetener', 'canned fish', 'chocolate'): 6.683151774376797e-05,
#  ('artif. sweetener',
#   'canned fish',
#   'chocolate',
#   'rolls/buns'): 6.683151774376797e-05,
#  ('artif. sweetener', 'canned fish', 'rolls/buns'): 6.683151774376797e-05,
#  ('artif. sweetener', 'cat food'): 6.683151774376797e-05,
#  ('artif. sweetener', 'cat food', 'hamburger meat'): 6.683151774376797e-05,
#  ('artif. sweetener',
#   'cat food',
#   'hamburger meat',
#   'packaged fruit/vegetables'): 6.683151774376797e-05,
#  ('artif. sweetener',
#   'cat food',
#   'hamburger meat',
#   'packaged fruit/vegetables',
#   'tropical fruit'): 6.683151774376797e-05,
#  ('artif. sweetener',
#   'cat food',
#   'hamburger meat',
#   'packaged fruit/vegetables',
#   'tropical fruit',
#   'whole milk'): 6.683151774376797e-05,
#  ('artif. sweetener',
#   'cat food',
#   'hamburger meat',
#   'packaged fruit/vegetables',
#   'whole milk'): 6.683151774376797e-05,
#  ('artif. sweetener',
#   'cat food',
#   'hamburger meat',
#   'tropical fruit'): 6.683151774376797e-05,
#  ('artif. sweetener',
#   'cat food',
#   'hamburger meat',
#   'tropical fruit',
#   'whole milk'): 6.683151774376797e-05,
#  ('artif. sweetener',
#   'cat food',
#   'hamburger meat',
#   'whole milk'): 6.683151774376797e-05,
#  ('artif. sweetener',
#   'cat food',
#   'packaged fruit/vegetables'): 6.683151774376797e-05,
#  ('artif. sweetener',
#   'cat food',
#   'packaged fruit/vegetables',
#   'tropical fruit'): 6.683151774376797e-05,
#  ('artif. sweetener',
#   'cat food',
#   'packaged fruit/vegetables',
#   'tropical fruit',
#   'whole milk'): 6.683151774376797e-05,
#  ('artif. sweetener',
#   'cat food',
#   'packaged fruit/vegetables',
#   'whole milk'): 6.683151774376797e-05,
#  ('artif. sweetener', 'cat food', 'tropical fruit'): 6.683151774376797e-05,
#  ('artif. sweetener',
#   'cat food',
#   'tropical fruit',
#   'whole milk'): 6.683151774376797e-05,
#  ('artif. sweetener', 'cat food', 'whole milk'): 6.683151774376797e-05,
#  ('artif. sweetener', 'chewing gum'): 6.683151774376797e-05,
#  ('artif. sweetener', 'chewing gum', 'sausage'): 6.683151774376797e-05,
#  ('artif. sweetener',
#   'chewing gum',
#   'sausage',
#   'uht-milk'): 6.683151774376797e-05,
#  ('artif. sweetener', 'chewing gum', 'uht-milk'): 6.683151774376797e-05,
#  ('artif. sweetener', 'chicken'): 6.683151774376797e-05,
#  ('artif. sweetener', 'chocolate'): 6.683151774376797e-05,
#  ('artif. sweetener', 'chocolate', 'rolls/buns'): 6.683151774376797e-05,
#  ('artif. sweetener', 'cocoa drinks'): 6.683151774376797e-05,
#  ('artif. sweetener', 'cocoa drinks', 'soda'): 6.683151774376797e-05,
#  ('artif. sweetener', 'curd'): 0.00013366303548753594,
#  ('artif. sweetener', 'curd', 'soda'): 6.683151774376797e-05,
#  ('artif. sweetener',
#   'curd',
#   'soda',
#   'specialty chocolate'): 6.683151774376797e-05,
#  ('artif. sweetener',
#   'curd',
#   'soda',
#   'specialty chocolate',
#   'sugar'): 6.683151774376797e-05,
#  ('artif. sweetener', 'curd', 'soda', 'sugar'): 6.683151774376797e-05,
#  ('artif. sweetener', 'curd', 'specialty chocolate'): 6.683151774376797e-05,
#  ('artif. sweetener',
#   'curd',
#   'specialty chocolate',
#   'sugar'): 6.683151774376797e-05,
#  ('artif. sweetener', 'curd', 'sugar'): 6.683151774376797e-05,
#  ('artif. sweetener', 'dessert'): 6.683151774376797e-05,
#  ('artif. sweetener', 'dessert', 'detergent'): 6.683151774376797e-05,
#  ('artif. sweetener', 'dessert', 'detergent', 'herbs'): 6.683151774376797e-05,
#  ('artif. sweetener', 'dessert', 'herbs'): 6.683151774376797e-05,
#  ('artif. sweetener', 'detergent'): 6.683151774376797e-05,
#  ('artif. sweetener', 'detergent', 'herbs'): 6.683151774376797e-05,
#  ('artif. sweetener', 'dog food'): 6.683151774376797e-05,
#  ('artif. sweetener', 'dog food', 'frankfurter'): 6.683151774376797e-05,
#  ('artif. sweetener',
#   'dog food',
#   'frankfurter',
#   'grapes'): 6.683151774376797e-05,
#  ('artif. sweetener',
#   'dog food',
#   'frankfurter',
#   'grapes',
#   'misc. beverages'): 6.683151774376797e-05,
#  ('artif. sweetener',
#   'dog food',
#   'frankfurter',
#   'grapes',
#   'misc. beverages',
#   'napkins'): 6.683151774376797e-05,
#  ('artif. sweetener',
#   'dog food',
#   'frankfurter',
#   'grapes',
#   'misc. beverages',
#   'napkins',
#   'sausage'): 6.683151774376797e-05,
#  ('artif. sweetener',
#   'dog food',
#   'frankfurter',
#   'grapes',
#   'misc. beverages',
#   'sausage'): 6.683151774376797e-05,
#  ('artif. sweetener',
#   'dog food',
#   'frankfurter',
#   'grapes',
#   'napkins'): 6.683151774376797e-05,
#  ('artif. sweetener',
#   'dog food',
#   'frankfurter',
#   'grapes',
#   'napkins',
#   'sausage'): 6.683151774376797e-05,
#  ('artif. sweetener',
#   'dog food',
#   'frankfurter',
#   'grapes',
#   'sausage'): 6.683151774376797e-05,
#  ('artif. sweetener',
#   'dog food',
#   'frankfurter',
#   'misc. beverages'): 6.683151774376797e-05,
#  ('artif. sweetener',
#   'dog food',
#   'frankfurter',
#   'misc. beverages',
#   'napkins'): 6.683151774376797e-05,
#  ('artif. sweetener',
#   'dog food',
#   'frankfurter',
#   'misc. beverages',
#   'napkins',
#   'sausage'): 6.683151774376797e-05,
#  ('artif. sweetener',
#   'dog food',
#   'frankfurter',
#   'misc. beverages',
#   'sausage'): 6.683151774376797e-05,
#  ('artif. sweetener',
#   'dog food',
#   'frankfurter',
#   'napkins'): 6.683151774376797e-05,
#  ('artif. sweetener',
#   'dog food',
#   'frankfurter',
#   'napkins',
#   'sausage'): 6.683151774376797e-05,
#  ('artif. sweetener',
#   'dog food',
#   'frankfurter',
#   'sausage'): 6.683151774376797e-05,
#  ('artif. sweetener', 'dog food', 'grapes'): 6.683151774376797e-05,
#  ('artif. sweetener',
#   'dog food',
#   'grapes',
#   'misc. beverages'): 6.683151774376797e-05,
#  ('artif. sweetener',
#   'dog food',
#   'grapes',
#   'misc. beverages',
#   'napkins'): 6.683151774376797e-05,
#  ('artif. sweetener',
#   'dog food',
#   'grapes',
#   'misc. beverages',
#   'napkins',
#   'sausage'): 6.683151774376797e-05,
#  ('artif. sweetener',
#   'dog food',
#   'grapes',
#   'misc. beverages',
#   'sausage'): 6.683151774376797e-05,
#  ('artif. sweetener', 'dog food', 'grapes', 'napkins'): 6.683151774376797e-05,
#  ('artif. sweetener',
#   'dog food',
#   'grapes',
#   'napkins',
#   'sausage'): 6.683151774376797e-05,
#  ('artif. sweetener', 'dog food', 'grapes', 'sausage'): 6.683151774376797e-05,
#  ('artif. sweetener', 'dog food', 'misc. beverages'): 6.683151774376797e-05,
#  ('artif. sweetener',
#   'dog food',
#   'misc. beverages',
#   'napkins'): 6.683151774376797e-05,
#  ('artif. sweetener',
#   'dog food',
#   'misc. beverages',
#   'napkins',
#   'sausage'): 6.683151774376797e-05,
#  ('artif. sweetener',
#   'dog food',
#   'misc. beverages',
#   'sausage'): 6.683151774376797e-05,
#  ('artif. sweetener', 'dog food', 'napkins'): 6.683151774376797e-05,
#  ('artif. sweetener', 'dog food', 'napkins', 'sausage'): 6.683151774376797e-05,
#  ('artif. sweetener', 'dog food', 'sausage'): 6.683151774376797e-05,
#  ('artif. sweetener', 'domestic eggs'): 0.00020049455323130388,
#  ('artif. sweetener', 'domestic eggs', 'frankfurter'): 6.683151774376797e-05,
#  ('artif. sweetener',
#   'domestic eggs',
#   'frankfurter',
#   'ham'): 6.683151774376797e-05,
#  ('artif. sweetener',
#   'domestic eggs',
#   'frankfurter',
#   'ham',
#   'margarine'): 6.683151774376797e-05,
#  ('artif. sweetener',
#   'domestic eggs',
#   'frankfurter',
#   'ham',
#   'margarine',
#   'other vegetables'): 6.683151774376797e-05,
#  ('artif. sweetener',
#   'domestic eggs',
#   'frankfurter',
#   'ham',
#   'other vegetables'): 6.683151774376797e-05,
#  ('artif. sweetener',
#   'domestic eggs',
#   'frankfurter',
#   'margarine'): 6.683151774376797e-05,
#  ('artif. sweetener',
#   'domestic eggs',
#   'frankfurter',
#   'margarine',
#   'other vegetables'): 6.683151774376797e-05,
#  ('artif. sweetener',
#   'domestic eggs',
#   'frankfurter',
#   'other vegetables'): 6.683151774376797e-05,
#  ('artif. sweetener', 'domestic eggs', 'ham'): 6.683151774376797e-05,
#  ('artif. sweetener',
#   'domestic eggs',
#   'ham',
#   'margarine'): 6.683151774376797e-05,
#  ('artif. sweetener',
#   'domestic eggs',
#   'ham',
#   'margarine',
#   'other vegetables'): 6.683151774376797e-05,
#  ('artif. sweetener',
#   'domestic eggs',
#   'ham',
#   'other vegetables'): 6.683151774376797e-05,
#  ('artif. sweetener', 'domestic eggs', 'margarine'): 6.683151774376797e-05,
#  ('artif. sweetener',
#   'domestic eggs',
#   'margarine',
#   'other vegetables'): 6.683151774376797e-05,
#  ('artif. sweetener',
#   'domestic eggs',
#   'other vegetables'): 6.683151774376797e-05,
#  ('artif. sweetener', 'domestic eggs', 'soda'): 6.683151774376797e-05,
#  ('artif. sweetener', 'domestic eggs', 'whole milk'): 6.683151774376797e-05,
#  ('artif. sweetener', 'frankfurter'): 0.00013366303548753594,
#  ('artif. sweetener', 'frankfurter', 'grapes'): 6.683151774376797e-05,
#  ('artif. sweetener',
#   'frankfurter',
#   'grapes',
#   'misc. beverages'): 6.683151774376797e-05,
#  ('artif. sweetener',
#   'frankfurter',
#   'grapes',
#   'misc. beverages',
#   'napkins'): 6.683151774376797e-05,
#  ('artif. sweetener',
#   'frankfurter',
#   'grapes',
#   'misc. beverages',
#   'napkins',
#   'sausage'): 6.683151774376797e-05,
#  ('artif. sweetener',
#   'frankfurter',
#   'grapes',
#   'misc. beverages',
#   'sausage'): 6.683151774376797e-05,
#  ('artif. sweetener',
#   'frankfurter',
#   'grapes',
#   'napkins'): 6.683151774376797e-05,
#  ('artif. sweetener',
#   'frankfurter',
#   'grapes',
#   'napkins',
#   'sausage'): 6.683151774376797e-05,
#  ('artif. sweetener',
#   'frankfurter',
#   'grapes',
#   'sausage'): 6.683151774376797e-05,
#  ('artif. sweetener', 'frankfurter', 'ham'): 6.683151774376797e-05,
#  ('artif. sweetener',
#   'frankfurter',
#   'ham',
#   'margarine'): 6.683151774376797e-05,
#  ('artif. sweetener',
#   'frankfurter',
#   'ham',
#   'margarine',
#   'other vegetables'): 6.683151774376797e-05,
#  ('artif. sweetener',
#   'frankfurter',
#   'ham',
#   'other vegetables'): 6.683151774376797e-05,
#  ('artif. sweetener', 'frankfurter', 'margarine'): 6.683151774376797e-05,
#  ('artif. sweetener',
#   'frankfurter',
#   'margarine',
#   'other vegetables'): 6.683151774376797e-05,
#  ('artif. sweetener', 'frankfurter', 'misc. beverages'): 6.683151774376797e-05,
#  ('artif. sweetener',
#   'frankfurter',
#   'misc. beverages',
#   'napkins'): 6.683151774376797e-05,
#  ('artif. sweetener',
#   'frankfurter',
#   'misc. beverages',
#   'napkins',
#   'sausage'): 6.683151774376797e-05,
#  ('artif. sweetener',
#   'frankfurter',
#   'misc. beverages',
#   'sausage'): 6.683151774376797e-05,
#  ('artif. sweetener', 'frankfurter', 'napkins'): 6.683151774376797e-05,
#  ('artif. sweetener',
#   'frankfurter',
#   'napkins',
#   'sausage'): 6.683151774376797e-05,
#  ('artif. sweetener',
#   'frankfurter',
#   'other vegetables'): 6.683151774376797e-05,
#  ('artif. sweetener', 'frankfurter', 'sausage'): 6.683151774376797e-05,
#  ('artif. sweetener', 'frozen meals'): 6.683151774376797e-05,
#  ('artif. sweetener', 'frozen meals', 'instant coffee'): 6.683151774376797e-05,
#  ('artif. sweetener',
#   'frozen meals',
#   'instant coffee',
#   'soda'): 6.683151774376797e-05,
#  ('artif. sweetener', 'frozen meals', 'soda'): 6.683151774376797e-05,
#  ('artif. sweetener', 'fruit/vegetable juice'): 6.683151774376797e-05,
#  ('artif. sweetener',
#   'fruit/vegetable juice',
#   'misc. beverages'): 6.683151774376797e-05,
#  ('artif. sweetener',
#   'fruit/vegetable juice',
#   'misc. beverages',
#   'newspapers'): 6.683151774376797e-05,
#  ('artif. sweetener',
#   'fruit/vegetable juice',
#   'newspapers'): 6.683151774376797e-05,
#  ('artif. sweetener', 'grapes'): 0.00013366303548753594,
#  ('artif. sweetener', 'grapes', 'misc. beverages'): 6.683151774376797e-05,
#  ('artif. sweetener',
#   'grapes',
#   'misc. beverages',
#   'napkins'): 6.683151774376797e-05,
#  ('artif. sweetener',
#   'grapes',
#   'misc. beverages',
#   'napkins',
#   'sausage'): 6.683151774376797e-05,
#  ('artif. sweetener',
#   'grapes',
#   'misc. beverages',
#   'sausage'): 6.683151774376797e-05,
#  ('artif. sweetener', 'grapes', 'napkins'): 6.683151774376797e-05,
#  ('artif. sweetener', 'grapes', 'napkins', 'sausage'): 6.683151774376797e-05,
#  ('artif. sweetener', 'grapes', 'sausage'): 6.683151774376797e-05,
#  ('artif. sweetener', 'grapes', 'shopping bags'): 6.683151774376797e-05,
#  ('artif. sweetener', 'ham'): 0.00013366303548753594,
#  ('artif. sweetener', 'ham', 'margarine'): 6.683151774376797e-05,
#  ('artif. sweetener',
#   'ham',
#   'margarine',
#   'other vegetables'): 6.683151774376797e-05,
#  ('artif. sweetener', 'ham', 'other vegetables'): 6.683151774376797e-05,
#  ('artif. sweetener', 'ham', 'whole milk'): 6.683151774376797e-05,
#  ('artif. sweetener', 'hamburger meat'): 6.683151774376797e-05,
#  ('artif. sweetener',
#   'hamburger meat',
#   'packaged fruit/vegetables'): 6.683151774376797e-05,
#  ('artif. sweetener',
#   'hamburger meat',
#   'packaged fruit/vegetables',
#   'tropical fruit'): 6.683151774376797e-05,
#  ('artif. sweetener',
#   'hamburger meat',
#   'packaged fruit/vegetables',
#   'tropical fruit',
#   'whole milk'): 6.683151774376797e-05,
#  ('artif. sweetener',
#   'hamburger meat',
#   'packaged fruit/vegetables',
#   'whole milk'): 6.683151774376797e-05,
#  ('artif. sweetener',
#   'hamburger meat',
#   'tropical fruit'): 6.683151774376797e-05,
#  ('artif. sweetener',
#   'hamburger meat',
#   'tropical fruit',
#   'whole milk'): 6.683151774376797e-05,
#  ('artif. sweetener', 'hamburger meat', 'whole milk'): 6.683151774376797e-05,
#  ('artif. sweetener', 'herbs'): 0.00013366303548753594,
#  ('artif. sweetener', 'honey'): 6.683151774376797e-05,
#  ('artif. sweetener', 'honey', 'other vegetables'): 6.683151774376797e-05,
#  ('artif. sweetener',
#   'honey',
#   'other vegetables',
#   'prosecco'): 6.683151774376797e-05,
#  ('artif. sweetener',
#   'honey',
#   'other vegetables',
#   'prosecco',
#   'sausage'): 6.683151774376797e-05,
#  ('artif. sweetener',
#   'honey',
#   'other vegetables',
#   'prosecco',
#   'sausage',
#   'shopping bags'): 6.683151774376797e-05,
#  ('artif. sweetener',
#   'honey',
#   'other vegetables',
#   'prosecco',
#   'sausage',
#   'shopping bags',
#   'waffles'): 6.683151774376797e-05,
#  ('artif. sweetener',
#   'honey',
#   'other vegetables',
#   'prosecco',
#   'sausage',
#   'shopping bags',
#   'waffles',
#   'whole milk'): 6.683151774376797e-05,
#  ('artif. sweetener',
#   'honey',
#   'other vegetables',
#   'prosecco',
#   'sausage',
#   'shopping bags',
#   'whole milk'): 6.683151774376797e-05,
#  ('artif. sweetener',
#   'honey',
#   'other vegetables',
#   'prosecco',
#   'sausage',
#   'waffles'): 6.683151774376797e-05,
#  ('artif. sweetener',
#   'honey',
#   'other vegetables',
#   'prosecco',
#   'sausage',
#   'waffles',
#   'whole milk'): 6.683151774376797e-05,
#  ('artif. sweetener',
#   'honey',
#   'other vegetables',
#   'prosecco',
#   'sausage',
#   'whole milk'): 6.683151774376797e-05,
#  ('artif. sweetener',
#   'honey',
#   'other vegetables',
#   'prosecco',
#   'shopping bags'): 6.683151774376797e-05,
#  ('artif. sweetener',
#   'honey',
#   'other vegetables',
#   'prosecco',
#   'shopping bags',
#   'waffles'): 6.683151774376797e-05,
#  ('artif. sweetener',
#   'honey',
#   'other vegetables',
#   'prosecco',
#   'shopping bags',
#   'waffles',
#   'whole milk'): 6.683151774376797e-05,
#  ('artif. sweetener',
#   'honey',
#   'other vegetables',
#   'prosecco',
#   'shopping bags',
#   'whole milk'): 6.683151774376797e-05,
#  ('artif. sweetener',
#   'honey',
#   'other vegetables',
#   'prosecco',
#   'waffles'): 6.683151774376797e-05,
#  ('artif. sweetener',
#   'honey',
#   'other vegetables',
#   'prosecco',
#   'waffles',
#   'whole milk'): 6.683151774376797e-05,
#  ('artif. sweetener',
#   'honey',
#   'other vegetables',
#   'prosecco',
#   'whole milk'): 6.683151774376797e-05,
#  ('artif. sweetener',
#   'honey',
#   'other vegetables',
#   'sausage'): 6.683151774376797e-05,
#  ('artif. sweetener',
#   'honey',
#   'other vegetables',
#   'sausage',
#   'shopping bags'): 6.683151774376797e-05,
#  ('artif. sweetener',
#   'honey',
#   'other vegetables',
#   'sausage',
#   'shopping bags',
#   'waffles'): 6.683151774376797e-05,
#  ('artif. sweetener',
#   'honey',
#   'other vegetables',
#   'sausage',
#   'shopping bags',
#   'waffles',
#   'whole milk'): 6.683151774376797e-05,
#  ('artif. sweetener',
#   'honey',
#   'other vegetables',
#   'sausage',
#   'shopping bags',
#   'whole milk'): 6.683151774376797e-05,
#  ('artif. sweetener',
#   'honey',
#   'other vegetables',
#   'sausage',
#   'waffles'): 6.683151774376797e-05,
#  ('artif. sweetener',
#   'honey',
#   'other vegetables',
#   'sausage',
#   'waffles',
#   'whole milk'): 6.683151774376797e-05,
#  ('artif. sweetener',
#   'honey',
#   'other vegetables',
#   'sausage',
#   'whole milk'): 6.683151774376797e-05,
#  ('artif. sweetener',
#   'honey',
#   'other vegetables',
#   'shopping bags'): 6.683151774376797e-05,
#  ('artif. sweetener',
#   'honey',
#   'other vegetables',
#   'shopping bags',
#   'waffles'): 6.683151774376797e-05,
#  ('artif. sweetener',
#   'honey',
#   'other vegetables',
#   'shopping bags',
#   'waffles',
#   'whole milk'): 6.683151774376797e-05,
#  ('artif. sweetener',
#   'honey',
#   'other vegetables',
#   'shopping bags',
#   'whole milk'): 6.683151774376797e-05,
#  ('artif. sweetener',
#   'honey',
#   'other vegetables',
#   'waffles'): 6.683151774376797e-05,
#  ('artif. sweetener',
#   'honey',
#   'other vegetables',
#   'waffles',
#   'whole milk'): 6.683151774376797e-05,
#  ('artif. sweetener',
#   'honey',
#   'other vegetables',
#   'whole milk'): 6.683151774376797e-05,
#  ('artif. sweetener', 'honey', 'prosecco'): 6.683151774376797e-05,
#  ('artif. sweetener', 'honey', 'prosecco', 'sausage'): 6.683151774376797e-05,
#  ('artif. sweetener',
#   'honey',
#   'prosecco',
#   'sausage',
#   'shopping bags'): 6.683151774376797e-05,
#  ('artif. sweetener',
#   'honey',
#   'prosecco',
#   'sausage',
#   'shopping bags',
#   'waffles'): 6.683151774376797e-05,
#  ('artif. sweetener',
#   'honey',
#   'prosecco',
#   'sausage',
#   'shopping bags',
#   'waffles',
#   'whole milk'): 6.683151774376797e-05,
#  ('artif. sweetener',
#   'honey',
#   'prosecco',
#   'sausage',
#   'shopping bags',
#   'whole milk'): 6.683151774376797e-05,
#  ('artif. sweetener',
#   'honey',
#   'prosecco',
#   'sausage',
#   'waffles'): 6.683151774376797e-05,
#  ('artif. sweetener',
#   'honey',
#   'prosecco',
#   'sausage',
#   'waffles',
#   'whole milk'): 6.683151774376797e-05,
#  ('artif. sweetener',
#   'honey',
#   'prosecco',
#   'sausage',
#   'whole milk'): 6.683151774376797e-05,
#  ('artif. sweetener',
#   'honey',
#   'prosecco',
#   'shopping bags'): 6.683151774376797e-05,
#  ('artif. sweetener',
#   'honey',
#   'prosecco',
#   'shopping bags',
#   'waffles'): 6.683151774376797e-05,
#  ('artif. sweetener',
#   'honey',
#   'prosecco',
#   'shopping bags',
#   'waffles',
#   'whole milk'): 6.683151774376797e-05,
#  ('artif. sweetener',
#   'honey',
#   'prosecco',
#   'shopping bags',
#   'whole milk'): 6.683151774376797e-05,
#  ('artif. sweetener', 'honey', 'prosecco', 'waffles'): 6.683151774376797e-05,
#  ('artif. sweetener',
#   'honey',
#   'prosecco',
#   'waffles',
#   'whole milk'): 6.683151774376797e-05,
#  ('artif. sweetener',
#   'honey',
#   'prosecco',
#   'whole milk'): 6.683151774376797e-05,
#  ('artif. sweetener', 'honey', 'sausage'): 6.683151774376797e-05,
#  ('artif. sweetener',
#   'honey',
#   'sausage',
#   'shopping bags'): 6.683151774376797e-05,
#  ('artif. sweetener',
#   'honey',
#   'sausage',
#   'shopping bags',
#   'waffles'): 6.683151774376797e-05,
#  ('artif. sweetener',
#   'honey',
#   'sausage',
#   'shopping bags',
#   'waffles',
#   'whole milk'): 6.683151774376797e-05,
#  ('artif. sweetener',
#   'honey',
#   'sausage',
#   'shopping bags',
#   'whole milk'): 6.683151774376797e-05,
#  ('artif. sweetener', 'honey', 'sausage', 'waffles'): 6.683151774376797e-05,
#  ('artif. sweetener',
#   'honey',
#   'sausage',
#   'waffles',
#   'whole milk'): 6.683151774376797e-05,
#  ('artif. sweetener', 'honey', 'sausage', 'whole milk'): 6.683151774376797e-05,
#  ('artif. sweetener', 'honey', 'shopping bags'): 6.683151774376797e-05,
#  ('artif. sweetener',
#   'honey',
#   'shopping bags',
#   'waffles'): 6.683151774376797e-05,
#  ('artif. sweetener',
#   'honey',
#   'shopping bags',
#   'waffles',
#   'whole milk'): 6.683151774376797e-05,
#  ('artif. sweetener',
#   'honey',
#   'shopping bags',
#   'whole milk'): 6.683151774376797e-05,
#  ('artif. sweetener', 'honey', 'waffles'): 6.683151774376797e-05,
#  ('artif. sweetener', 'honey', 'waffles', 'whole milk'): 6.683151774376797e-05,
#  ('artif. sweetener', 'honey', 'whole milk'): 6.683151774376797e-05,
#  ('artif. sweetener', 'hygiene articles'): 6.683151774376797e-05,
#  ('artif. sweetener', 'hygiene articles', 'pip fruit'): 6.683151774376797e-05,
#  ('artif. sweetener', 'ice cream'): 6.683151774376797e-05,
#  ('artif. sweetener', 'ice cream', 'turkey'): 6.683151774376797e-05,
#  ('artif. sweetener',
#   'ice cream',
#   'turkey',
#   'whole milk'): 6.683151774376797e-05,
#  ('artif. sweetener', 'ice cream', 'whole milk'): 6.683151774376797e-05,
#  ('artif. sweetener', 'instant coffee'): 6.683151774376797e-05,
#  ('artif. sweetener', 'instant coffee', 'soda'): 6.683151774376797e-05,
#  ('artif. sweetener', 'margarine'): 6.683151774376797e-05,
#  ('artif. sweetener', 'margarine', 'other vegetables'): 6.683151774376797e-05,
#  ('artif. sweetener', 'misc. beverages'): 0.00013366303548753594,
#  ('artif. sweetener', 'misc. beverages', 'napkins'): 6.683151774376797e-05,
#  ('artif. sweetener',
#   'misc. beverages',
#   'napkins',
#   'sausage'): 6.683151774376797e-05,
#  ('artif. sweetener', 'misc. beverages', 'newspapers'): 6.683151774376797e-05,
#  ('artif. sweetener', 'misc. beverages', 'sausage'): 6.683151774376797e-05,
#  ('artif. sweetener', 'napkins'): 0.00013366303548753594,
#  ('artif. sweetener', 'napkins', 'sausage'): 6.683151774376797e-05,
#  ('artif. sweetener', 'napkins', 'whole milk'): 6.683151774376797e-05,
#  ('artif. sweetener', 'newspapers'): 6.683151774376797e-05,
#  ('artif. sweetener', 'other vegetables'): 0.00020049455323130388,
#  ('artif. sweetener', 'other vegetables', 'prosecco'): 6.683151774376797e-05,
#  ('artif. sweetener',
#   'other vegetables',
#   'prosecco',
#   'sausage'): 6.683151774376797e-05,
#  ('artif. sweetener',
#   'other vegetables',
#   'prosecco',
#   'sausage',
#   'shopping bags'): 6.683151774376797e-05,
#  ('artif. sweetener',
#   'other vegetables',
#   'prosecco',
#   'sausage',
#   'shopping bags',
#   'waffles'): 6.683151774376797e-05,
#  ('artif. sweetener',
#   'other vegetables',
#   'prosecco',
#   'sausage',
#   'shopping bags',
#   'waffles',
#   'whole milk'): 6.683151774376797e-05,
#  ('artif. sweetener',
#   'other vegetables',
#   'prosecco',
# ...
#  ('baking powder',
#   'butter',
#   'butter milk',
#   'long life bakery product',
#   'uht-milk'): 6.683151774376797e-05,
#  ('baking powder', 'butter', 'butter milk', 'uht-milk'): 6.683151774376797e-05,
#  ('baking powder', 'butter', 'canned beer'): 0.00013366303548753594,
#  ('baking powder',
#   'butter',
#   'canned beer',
#   'long life bakery product'): 6.683151774376797e-05,
#  ('baking powder',
#   'butter',
#   'canned beer',
#   'long life bakery product',
#   'uht-milk'): 6.683151774376797e-05,
#  ('baking powder', 'butter', 'canned beer', 'uht-milk'): 6.683151774376797e-05,
#  ('baking powder', 'butter', 'curd'): 6.683151774376797e-05,
#  ('baking powder', 'butter', 'curd', 'dishes'): 6.683151774376797e-05,
#  ('baking powder',
#   'butter',
#   'curd',
#   'dishes',
#   'margarine'): 6.683151774376797e-05,
#  ('baking powder',
#   'butter',
#   'curd',
#   'dishes',
#   'margarine',
#   'pastry'): 6.683151774376797e-05,
#  ('baking powder',
#   'butter',
#   'curd',
#   'dishes',
#   'pastry'): 6.683151774376797e-05,
#  ('baking powder', 'butter', 'curd', 'margarine'): 6.683151774376797e-05,
#  ('baking powder',
#   'butter',
#   'curd',
#   'margarine',
#   'pastry'): 6.683151774376797e-05,
#  ('baking powder', 'butter', 'curd', 'pastry'): 6.683151774376797e-05,
#  ('baking powder', 'butter', 'dishes'): 6.683151774376797e-05,
#  ('baking powder', 'butter', 'dishes', 'margarine'): 6.683151774376797e-05,
#  ('baking powder',
#   'butter',
#   'dishes',
#   'margarine',
#   'pastry'): 6.683151774376797e-05,
#  ('baking powder', 'butter', 'dishes', 'pastry'): 6.683151774376797e-05,
#  ('baking powder',
#   'butter',
#   'long life bakery product'): 6.683151774376797e-05,
#  ('baking powder',
#   'butter',
#   'long life bakery product',
#   'uht-milk'): 6.683151774376797e-05,
#  ('baking powder', 'butter', 'margarine'): 6.683151774376797e-05,
#  ('baking powder', 'butter', 'margarine', 'pastry'): 6.683151774376797e-05,
#  ('baking powder', 'butter', 'pastry'): 6.683151774376797e-05,
#  ('baking powder', 'butter', 'uht-milk'): 6.683151774376797e-05,
#  ('baking powder', 'butter milk'): 0.00020049455323130388,
#  ('baking powder', 'butter milk', 'canned beer'): 6.683151774376797e-05,
#  ('baking powder',
#   'butter milk',
#   'canned beer',
#   'long life bakery product'): 6.683151774376797e-05,
#  ('baking powder',
#   'butter milk',
#   'canned beer',
#   'long life bakery product',
#   'uht-milk'): 6.683151774376797e-05,
#  ('baking powder',
#   'butter milk',
#   'canned beer',
#   'uht-milk'): 6.683151774376797e-05,
#  ('baking powder',
#   'butter milk',
#   'long life bakery product'): 6.683151774376797e-05,
#  ('baking powder',
#   'butter milk',
#   'long life bakery product',
#   'uht-milk'): 6.683151774376797e-05,
#  ('baking powder', 'butter milk', 'salty snack'): 6.683151774376797e-05,
#  ('baking powder',
#   'butter milk',
#   'salty snack',
#   'soda'): 6.683151774376797e-05,
#  ('baking powder', 'butter milk', 'shopping bags'): 6.683151774376797e-05,
#  ('baking powder', 'butter milk', 'soda'): 6.683151774376797e-05,
#  ('baking powder', 'butter milk', 'uht-milk'): 6.683151774376797e-05,
#  ('baking powder', 'cake bar'): 6.683151774376797e-05,
#  ('baking powder', 'cake bar', 'canned beer'): 6.683151774376797e-05,
#  ('baking powder',
#   'cake bar',
#   'canned beer',
#   'newspapers'): 6.683151774376797e-05,
#  ('baking powder',
#   'cake bar',
#   'canned beer',
#   'newspapers',
#   'pastry'): 6.683151774376797e-05,
#  ('baking powder',
#   'cake bar',
#   'canned beer',
#   'newspapers',
#   'pastry',
#   'yogurt'): 6.683151774376797e-05,
#  ('baking powder',
#   'cake bar',
#   'canned beer',
#   'newspapers',
#   'yogurt'): 6.683151774376797e-05,
#  ('baking powder', 'cake bar', 'canned beer', 'pastry'): 6.683151774376797e-05,
#  ('baking powder',
#   'cake bar',
#   'canned beer',
#   'pastry',
#   'yogurt'): 6.683151774376797e-05,
#  ('baking powder', 'cake bar', 'canned beer', 'yogurt'): 6.683151774376797e-05,
#  ('baking powder', 'cake bar', 'newspapers'): 6.683151774376797e-05,
#  ('baking powder', 'cake bar', 'newspapers', 'pastry'): 6.683151774376797e-05,
#  ('baking powder',
#   'cake bar',
#   'newspapers',
#   'pastry',
#   'yogurt'): 6.683151774376797e-05,
#  ('baking powder', 'cake bar', 'newspapers', 'yogurt'): 6.683151774376797e-05,
#  ('baking powder', 'cake bar', 'pastry'): 6.683151774376797e-05,
#  ('baking powder', 'cake bar', 'pastry', 'yogurt'): 6.683151774376797e-05,
#  ('baking powder', 'cake bar', 'yogurt'): 6.683151774376797e-05,
#  ('baking powder', 'candy'): 0.00020049455323130388,
#  ('baking powder', 'candy', 'canned fish'): 6.683151774376797e-05,
#  ('baking powder', 'candy', 'cling film/bags'): 6.683151774376797e-05,
#  ('baking powder',
#   'candy',
#   'cling film/bags',
#   'newspapers'): 6.683151774376797e-05,
#  ('baking powder',
#   'candy',
#   'cling film/bags',
#   'newspapers',
#   'whipped/sour cream'): 6.683151774376797e-05,
#  ('baking powder',
#   'candy',
#   'cling film/bags',
#   'newspapers',
#   'whipped/sour cream',
#   'whole milk'): 6.683151774376797e-05,
#  ('baking powder',
#   'candy',
#   'cling film/bags',
#   'newspapers',
#   'whole milk'): 6.683151774376797e-05,
#  ('baking powder',
#   'candy',
#   'cling film/bags',
#   'whipped/sour cream'): 6.683151774376797e-05,
#  ('baking powder',
#   'candy',
#   'cling film/bags',
#   'whipped/sour cream',
#   'whole milk'): 6.683151774376797e-05,
#  ('baking powder',
#   'candy',
#   'cling film/bags',
#   'whole milk'): 6.683151774376797e-05,
#  ('baking powder', 'candy', 'newspapers'): 6.683151774376797e-05,
#  ('baking powder',
#   'candy',
#   'newspapers',
#   'whipped/sour cream'): 6.683151774376797e-05,
#  ('baking powder',
#   'candy',
#   'newspapers',
#   'whipped/sour cream',
#   'whole milk'): 6.683151774376797e-05,
#  ('baking powder', 'candy', 'newspapers', 'whole milk'): 6.683151774376797e-05,
#  ('baking powder', 'candy', 'other vegetables'): 6.683151774376797e-05,
#  ('baking powder',
#   'candy',
#   'other vegetables',
#   'yogurt'): 6.683151774376797e-05,
#  ('baking powder', 'candy', 'whipped/sour cream'): 6.683151774376797e-05,
#  ('baking powder',
#   'candy',
#   'whipped/sour cream',
#   'whole milk'): 6.683151774376797e-05,
#  ('baking powder', 'candy', 'whole milk'): 6.683151774376797e-05,
#  ('baking powder', 'candy', 'yogurt'): 6.683151774376797e-05,
#  ('baking powder', 'canned beer'): 0.0006014836596939117,
#  ('baking powder', 'canned beer', 'chicken'): 6.683151774376797e-05,
#  ('baking powder',
#   'canned beer',
#   'chicken',
#   'rolls/buns'): 6.683151774376797e-05,
#  ('baking powder',
#   'canned beer',
#   'chicken',
#   'rolls/buns',
#   'whipped/sour cream'): 6.683151774376797e-05,
#  ('baking powder',
#   'canned beer',
#   'chicken',
#   'whipped/sour cream'): 6.683151774376797e-05,
#  ('baking powder', 'canned beer', 'curd'): 6.683151774376797e-05,
#  ('baking powder', 'canned beer', 'curd', 'sausage'): 6.683151774376797e-05,
#  ('baking powder',
#   'canned beer',
#   'curd',
#   'sausage',
#   'white bread'): 6.683151774376797e-05,
#  ('baking powder',
#   'canned beer',
#   'curd',
#   'white bread'): 6.683151774376797e-05,
#  ('baking powder',
#   'canned beer',
#   'long life bakery product'): 6.683151774376797e-05,
#  ('baking powder',
#   'canned beer',
#   'long life bakery product',
#   'uht-milk'): 6.683151774376797e-05,
#  ('baking powder', 'canned beer', 'newspapers'): 6.683151774376797e-05,
#  ('baking powder',
#   'canned beer',
#   'newspapers',
#   'pastry'): 6.683151774376797e-05,
#  ('baking powder',
#   'canned beer',
#   'newspapers',
#   'pastry',
#   'yogurt'): 6.683151774376797e-05,
#  ('baking powder',
#   'canned beer',
#   'newspapers',
#   'yogurt'): 6.683151774376797e-05,
#  ('baking powder', 'canned beer', 'pastry'): 6.683151774376797e-05,
#  ('baking powder', 'canned beer', 'pastry', 'yogurt'): 6.683151774376797e-05,
#  ('baking powder', 'canned beer', 'rolls/buns'): 0.00013366303548753594,
#  ('baking powder',
#   'canned beer',
#   'rolls/buns',
#   'whipped/sour cream'): 6.683151774376797e-05,
#  ('baking powder', 'canned beer', 'sausage'): 6.683151774376797e-05,
#  ('baking powder',
#   'canned beer',
#   'sausage',
#   'white bread'): 6.683151774376797e-05,
#  ('baking powder',
#   'canned beer',
#   'specialty chocolate'): 6.683151774376797e-05,
#  ('baking powder', 'canned beer', 'uht-milk'): 6.683151774376797e-05,
#  ('baking powder', 'canned beer', 'whipped/sour cream'): 6.683151774376797e-05,
#  ('baking powder', 'canned beer', 'white bread'): 6.683151774376797e-05,
#  ('baking powder', 'canned beer', 'yogurt'): 6.683151774376797e-05,
#  ('baking powder', 'canned fish'): 6.683151774376797e-05,
#  ('baking powder', 'canned vegetables'): 6.683151774376797e-05,
#  ('baking powder', 'canned vegetables', 'detergent'): 6.683151774376797e-05,
#  ('baking powder',
#   'canned vegetables',
#   'detergent',
#   'domestic eggs'): 6.683151774376797e-05,
#  ('baking powder',
#   'canned vegetables',
#   'detergent',
#   'domestic eggs',
#   'hygiene articles'): 6.683151774376797e-05,
#  ('baking powder',
#   'canned vegetables',
#   'detergent',
#   'domestic eggs',
#   'hygiene articles',
#   'whole milk'): 6.683151774376797e-05,
#  ('baking powder',
#   'canned vegetables',
#   'detergent',
#   'domestic eggs',
#   'whole milk'): 6.683151774376797e-05,
#  ('baking powder',
#   'canned vegetables',
#   'detergent',
#   'hygiene articles'): 6.683151774376797e-05,
#  ('baking powder',
#   'canned vegetables',
#   'detergent',
#   'hygiene articles',
#   'whole milk'): 6.683151774376797e-05,
#  ('baking powder',
#   'canned vegetables',
#   'detergent',
#   'whole milk'): 6.683151774376797e-05,
#  ('baking powder',
#   'canned vegetables',
#   'domestic eggs'): 6.683151774376797e-05,
#  ('baking powder',
#   'canned vegetables',
#   'domestic eggs',
#   'hygiene articles'): 6.683151774376797e-05,
#  ('baking powder',
#   'canned vegetables',
#   'domestic eggs',
#   'hygiene articles',
#   'whole milk'): 6.683151774376797e-05,
#  ('baking powder',
#   'canned vegetables',
#   'domestic eggs',
#   'whole milk'): 6.683151774376797e-05,
#  ('baking powder',
#   'canned vegetables',
#   'hygiene articles'): 6.683151774376797e-05,
#  ('baking powder',
#   'canned vegetables',
#   'hygiene articles',
#   'whole milk'): 6.683151774376797e-05,
#  ('baking powder', 'canned vegetables', 'whole milk'): 6.683151774376797e-05,
#  ('baking powder', 'cat food'): 6.683151774376797e-05,
#  ('baking powder', 'cat food', 'whipped/sour cream'): 6.683151774376797e-05,
#  ('baking powder', 'chewing gum'): 6.683151774376797e-05,
#  ('baking powder', 'chewing gum', 'chicken'): 6.683151774376797e-05,
#  ('baking powder', 'chewing gum', 'chicken', 'meat'): 6.683151774376797e-05,
#  ('baking powder',
#   'chewing gum',
#   'chicken',
#   'meat',
#   'shopping bags'): 6.683151774376797e-05,
#  ('baking powder',
#   'chewing gum',
#   'chicken',
#   'shopping bags'): 6.683151774376797e-05,
#  ('baking powder', 'chewing gum', 'meat'): 6.683151774376797e-05,
#  ('baking powder',
#   'chewing gum',
#   'meat',
#   'shopping bags'): 6.683151774376797e-05,
#  ('baking powder', 'chewing gum', 'shopping bags'): 6.683151774376797e-05,
#  ('baking powder', 'chicken'): 0.00026732607097507187,
#  ('baking powder', 'chicken', 'curd'): 6.683151774376797e-05,
#  ('baking powder', 'chicken', 'meat'): 6.683151774376797e-05,
#  ('baking powder', 'chicken', 'meat', 'shopping bags'): 6.683151774376797e-05,
#  ('baking powder', 'chicken', 'rolls/buns'): 6.683151774376797e-05,
#  ('baking powder',
#   'chicken',
#   'rolls/buns',
#   'whipped/sour cream'): 6.683151774376797e-05,
#  ('baking powder', 'chicken', 'shopping bags'): 6.683151774376797e-05,
#  ('baking powder', 'chicken', 'whipped/sour cream'): 6.683151774376797e-05,
#  ('baking powder', 'chocolate'): 0.00013366303548753594,
#  ('baking powder', 'chocolate', 'frozen vegetables'): 6.683151774376797e-05,
#  ('baking powder',
#   'chocolate',
#   'frozen vegetables',
#   'whipped/sour cream'): 6.683151774376797e-05,
#  ('baking powder', 'chocolate', 'whipped/sour cream'): 6.683151774376797e-05,
#  ('baking powder', 'citrus fruit'): 0.00020049455323130388,
#  ('baking powder', 'cling film/bags'): 6.683151774376797e-05,
#  ('baking powder', 'cling film/bags', 'newspapers'): 6.683151774376797e-05,
#  ('baking powder',
#   'cling film/bags',
#   'newspapers',
#   'whipped/sour cream'): 6.683151774376797e-05,
#  ('baking powder',
#   'cling film/bags',
#   'newspapers',
#   'whipped/sour cream',
#   'whole milk'): 6.683151774376797e-05,
#  ('baking powder',
#   'cling film/bags',
#   'newspapers',
#   'whole milk'): 6.683151774376797e-05,
#  ('baking powder',
#   'cling film/bags',
#   'whipped/sour cream'): 6.683151774376797e-05,
#  ('baking powder',
#   'cling film/bags',
#   'whipped/sour cream',
#   'whole milk'): 6.683151774376797e-05,
#  ('baking powder', 'cling film/bags', 'whole milk'): 6.683151774376797e-05,
#  ('baking powder', 'coffee'): 0.0003341575887188398,
#  ('baking powder', 'coffee', 'condensed milk'): 6.683151774376797e-05,
#  ('baking powder',
#   'coffee',
#   'condensed milk',
#   'frankfurter'): 6.683151774376797e-05,
#  ('baking powder', 'coffee', 'curd'): 6.683151774376797e-05,
#  ('baking powder', 'coffee', 'frankfurter'): 6.683151774376797e-05,
#  ('baking powder', 'coffee', 'fruit/vegetable juice'): 6.683151774376797e-05,
#  ('baking powder',
#   'coffee',
#   'fruit/vegetable juice',
#   'newspapers'): 6.683151774376797e-05,
#  ('baking powder',
#   'coffee',
#   'fruit/vegetable juice',
#   'newspapers',
#   'pastry'): 6.683151774376797e-05,
#  ('baking powder',
#   'coffee',
#   'fruit/vegetable juice',
#   'newspapers',
#   'pastry',
#   'processed cheese'): 6.683151774376797e-05,
#  ('baking powder',
#   'coffee',
#   'fruit/vegetable juice',
#   'newspapers',
#   'pastry',
#   'processed cheese',
#   'whole milk'): 6.683151774376797e-05,
#  ('baking powder',
#   'coffee',
#   'fruit/vegetable juice',
#   'newspapers',
#   'pastry',
#   'whole milk'): 6.683151774376797e-05,
#  ('baking powder',
#   'coffee',
#   'fruit/vegetable juice',
#   'newspapers',
#   'processed cheese'): 6.683151774376797e-05,
#  ('baking powder',
#   'coffee',
#   'fruit/vegetable juice',
#   'newspapers',
#   'processed cheese',
#   'whole milk'): 6.683151774376797e-05,
#  ('baking powder',
#   'coffee',
#   'fruit/vegetable juice',
#   'newspapers',
#   'whole milk'): 6.683151774376797e-05,
#  ('baking powder',
#   'coffee',
#   'fruit/vegetable juice',
#   'pastry'): 6.683151774376797e-05,
#  ('baking powder',
#   'coffee',
#   'fruit/vegetable juice',
#   'pastry',
#   'processed cheese'): 6.683151774376797e-05,
#  ('baking powder',
#   'coffee',
#   'fruit/vegetable juice',
#   'pastry',
#   'processed cheese',
#   'whole milk'): 6.683151774376797e-05,
#  ('baking powder',
#   'coffee',
#   'fruit/vegetable juice',
#   'pastry',
#   'whole milk'): 6.683151774376797e-05,
#  ('baking powder',
#   'coffee',
#   'fruit/vegetable juice',
#   'processed cheese'): 6.683151774376797e-05,
#  ('baking powder',
#   'coffee',
#   'fruit/vegetable juice',
#   'processed cheese',
#   'whole milk'): 6.683151774376797e-05,
#  ('baking powder',
#   'coffee',
#   'fruit/vegetable juice',
#   'whole milk'): 6.683151774376797e-05,
#  ('baking powder', 'coffee', 'newspapers'): 6.683151774376797e-05,
#  ('baking powder', 'coffee', 'newspapers', 'pastry'): 6.683151774376797e-05,
#  ('baking powder',
#   'coffee',
#   'newspapers',
#   'pastry',
#   'processed cheese'): 6.683151774376797e-05,
#  ('baking powder',
#   'coffee',
#   'newspapers',
#   'pastry',
#   'processed cheese',
#   'whole milk'): 6.683151774376797e-05,
#  ('baking powder',
#   'coffee',
#   'newspapers',
#   'pastry',
#   'whole milk'): 6.683151774376797e-05,
#  ('baking powder',
#   'coffee',
#   'newspapers',
#   'processed cheese'): 6.683151774376797e-05,
#  ('baking powder',
#   'coffee',
#   'newspapers',
#   'processed cheese',
#   'whole milk'): 6.683151774376797e-05,
#  ('baking powder',
#   'coffee',
#   'newspapers',
#   'whole milk'): 6.683151774376797e-05,
#  ('baking powder', 'coffee', 'pastry'): 6.683151774376797e-05,
#  ('baking powder',
#   'coffee',
#   'pastry',
#   'processed cheese'): 6.683151774376797e-05,
#  ('baking powder',
#   'coffee',
#   'pastry',
#   'processed cheese',
#   'whole milk'): 6.683151774376797e-05,
#  ('baking powder', 'coffee', 'pastry', 'whole milk'): 6.683151774376797e-05,
#  ('baking powder', 'coffee', 'processed cheese'): 6.683151774376797e-05,
#  ('baking powder',
#   'coffee',
#   'processed cheese',
#   'whole milk'): 6.683151774376797e-05,
#  ('baking powder', 'coffee', 'whole milk'): 6.683151774376797e-05,
#  ('baking powder', 'condensed milk'): 0.00013366303548753594,
#  ('baking powder', 'condensed milk', 'frankfurter'): 6.683151774376797e-05,
#  ...}

# %%
len(supports)
# Out:
# 63435

# %%
# definiujemy funkcje obliczajace support, confidence i lift


def support(supports, products: tuple[str, ...]) -> float:
    key = tuple(sorted(products))
    return supports.get(key, 0)


def confidence(
    supports, prior_products: tuple[str, ...], following_products: tuple[str]
) -> float:
    if support(supports, prior_products) == 0:
        return 0
    return support(
        supports, tuple(set(prior_products).union(set(following_products)))
    ) / support(supports, prior_products)


def lift(supports, prior_products: tuple[str, ...], following_products: tuple[str]) -> float:
    if (support(supports, prior_products) * support(supports, following_products)) == 0:
        return 0
    return support(
        supports, tuple(set(prior_products).union(set(following_products)))
    ) / (support(supports, prior_products) * support(supports, following_products))

# %%
print(support(supports, ('whole milk', 'rolls/buns')))
print(confidence(supports, ('whole milk', 'rolls/buns'), ('yogurt', )))
print(lift(supports, ('whole milk', 'rolls/buns'), ('yogurt', )))
# Out:
# 0.013967787208447505
# 0.09569377990430622
# 1.1142926293448512

# %% [markdown]
# ## Część 3. - generowanie rekomendacji

# %%
from itertools import combinations, chain
# wyznaczamy liste potencjalnych rekomendacji
# rekomendowane artykuly powinny miec lift > 1 i mozliwie wysokie confidence

def generate_next_product_candidates(basket: tuple[str], products: list[str], supports) -> list[tuple[str, tuple[str], float, float]]:
    candidates = []
    for subbasket in chain.from_iterable(combinations(basket, r) for r in range(len(basket)+1)):
        for product in products:
            if product not in subbasket:
                lift_value = lift(supports, subbasket, (product, ))
                if lift_value > 1:
                    conf = confidence(supports, basket, (product, ))
                    if (conf, product) not in candidates:
                        candidates.append((conf, product))
    candidates = sorted(candidates, key=lambda x: x[0], reverse=True)
    return candidates

# %%
print(baskets[1])
generate_next_product_candidates(baskets[1], products, supports)
# Out:
# {'whole milk', 'semi-finished bread', 'yogurt', 'sausage'}
# [(1.0, 'semi-finished bread'),
#  (1.0, 'sausage'),
#  (1.0, 'whole milk'),
#  (1.0, 'yogurt'),
#  (0.5, 'other vegetables'),
#  (0.0, 'artif. sweetener'),
#  (0.0, 'bathroom cleaner'),
#  (0.0, 'brandy'),
#  (0.0, 'candles'),
#  (0.0, 'canned fruit'),
#  (0.0, 'canned vegetables'),
#  (0.0, 'chocolate marshmallow'),
#  (0.0, 'cookware'),
#  (0.0, 'detergent'),
#  (0.0, 'dish cleaner'),
#  (0.0, 'finished products'),
#  (0.0, 'hair spray'),
#  (0.0, 'ham'),
#  (0.0, 'honey'),
#  (0.0, 'house keeping products'),
#  (0.0, 'light bulbs'),
#  (0.0, 'liqueur'),
#  (0.0, 'nut snack'),
#  (0.0, 'nuts/prunes'),
#  (0.0, 'organic products'),
#  (0.0, 'popcorn'),
#  (0.0, 'ready soups'),
#  (0.0, 'rubbing alcohol'),
#  (0.0, 'salad dressing'),
#  (0.0, 'softener'),
#  (0.0, 'syrup'),
#  (0.0, 'beef'),
#  (0.0, 'beverages'),
#  (0.0, 'canned beer'),
#  (0.0, 'cereals'),
#  (0.0, 'curd cheese'),
#  (0.0, 'decalcifier'),
#  (0.0, 'dishes'),
#  (0.0, 'dog food'),
#  (0.0, 'domestic eggs'),
#  (0.0, 'flour'),
#  (0.0, 'frozen dessert'),
#  (0.0, 'frozen fish'),
#  (0.0, 'frozen potato products'),
#  (0.0, 'fruit/vegetable juice'),
#  (0.0, 'ice cream'),
#  (0.0, 'instant coffee'),
#  (0.0, 'instant food products'),
#  (0.0, 'ketchup'),
#  (0.0, 'liquor'),
#  (0.0, 'liquor (appetizer)'),
#  (0.0, 'long life bakery product'),
#  (0.0, 'mustard'),
#  (0.0, 'napkins'),
#  (0.0, 'organic sausage'),
#  (0.0, 'root vegetables'),
#  (0.0, 'rum'),
#  (0.0, 'salt'),
#  (0.0, 'salty snack'),
#  (0.0, 'sliced cheese'),
#  (0.0, 'soft cheese'),
#  (0.0, 'sparkling wine'),
#  (0.0, 'spices'),
#  (0.0, 'tropical fruit'),
#  (0.0, 'turkey'),
#  (0.0, 'waffles'),
#  (0.0, 'white bread'),
#  (0.0, 'white wine'),
#  (0.0, 'abrasive cleaner'),
#  (0.0, 'bags'),
#  (0.0, 'canned fish'),
#  (0.0, 'chewing gum'),
#  (0.0, 'citrus fruit'),
#  (0.0, 'flower soil/fertilizer'),
#  (0.0, 'frozen chicken'),
#  (0.0, 'hard cheese'),
#  (0.0, 'herbs'),
#  (0.0, 'jam'),
#  (0.0, 'pasta'),
#  (0.0, 'pet care'),
#  (0.0, 'pot plants'),
#  (0.0, 'pudding powder'),
#  (0.0, 'specialty bar'),
#  (0.0, 'specialty vegetables'),
#  (0.0, 'tidbits'),
#  (0.0, 'whisky'),
#  (0.0, 'baking powder'),
#  (0.0, 'bottled beer'),
#  (0.0, 'cake bar'),
#  (0.0, 'cocoa drinks'),
#  (0.0, 'cooking chocolate'),
#  (0.0, 'cream'),
#  (0.0, 'curd'),
#  (0.0, 'dessert'),
#  (0.0, 'female sanitary products'),
#  (0.0, 'fish'),
#  (0.0, 'flower (seeds)'),
#  (0.0, 'frozen fruits'),
#  (0.0, 'frozen meals'),
#  (0.0, 'frozen vegetables'),
#  (0.0, 'grapes'),
#  (0.0, 'hygiene articles'),
#  (0.0, 'kitchen towels'),
#  (0.0, 'mayonnaise'),
#  (0.0, 'meat spreads'),
#  (0.0, 'misc. beverages'),
#  (0.0, 'packaged fruit/vegetables'),
#  (0.0, 'pastry'),
#  (0.0, 'prosecco'),
#  (0.0, 'snack products'),
#  (0.0, 'soda'),
#  (0.0, 'spread cheese'),
#  (0.0, 'tea'),
#  (0.0, 'zwieback'),
#  (0.0, 'butter'),
#  (0.0, 'candy'),
#  (0.0, 'chicken'),
#  (0.0, 'chocolate'),
#  (0.0, 'cream cheese '),
#  (0.0, 'frankfurter'),
#  (0.0, 'hamburger meat'),
#  (0.0, 'margarine'),
#  (0.0, 'processed cheese'),
#  (0.0, 'specialty chocolate'),
#  (0.0, 'berries'),
#  (0.0, 'butter milk'),
#  (0.0, 'cling film/bags'),
#  (0.0, 'liver loaf'),
#  (0.0, 'newspapers'),
#  (0.0, 'onions'),
#  (0.0, 'photo/film'),
#  (0.0, 'pip fruit'),
#  (0.0, 'pork'),
#  (0.0, 'rolls/buns'),
#  (0.0, 'shopping bags'),
#  (0.0, 'sweet spreads'),
#  (0.0, 'condensed milk'),
#  (0.0, 'oil'),
#  (0.0, 'vinegar'),
#  (0.0, 'uht-milk'),
#  (0.0, 'coffee'),
#  (0.0, 'sugar'),
#  (0.0, 'whipped/sour cream'),
#  (0.0, 'cat food')]

# %%
print(baskets[33])
generate_next_product_candidates(baskets[33], products, supports)
# Out:
# {'root vegetables', 'domestic eggs', 'yogurt', 'white wine', 'tropical fruit', 'photo/film', 'soda'}
# [(1.0, 'photo/film'),
#  (1.0, 'domestic eggs'),
#  (1.0, 'soda'),
#  (1.0, 'white wine'),
#  (1.0, 'tropical fruit'),
#  (1.0, 'yogurt'),
#  (1.0, 'root vegetables'),
#  (0.0, 'brandy'),
#  (0.0, 'cream'),
#  (0.0, 'decalcifier'),
#  (0.0, 'dog food'),
#  (0.0, 'fish'),
#  (0.0, 'flower (seeds)'),
#  (0.0, 'frozen dessert'),
#  (0.0, 'frozen fruits'),
#  (0.0, 'frozen potato products'),
#  (0.0, 'frozen vegetables'),
#  (0.0, 'grapes'),
#  (0.0, 'hygiene articles'),
#  (0.0, 'instant food products'),
#  (0.0, 'male cosmetics'),
#  (0.0, 'mayonnaise'),
#  (0.0, 'meat'),
#  (0.0, 'nut snack'),
#  (0.0, 'nuts/prunes'),
#  (0.0, 'organic products'),
#  (0.0, 'pet care'),
#  (0.0, 'potato products'),
#  (0.0, 'processed cheese'),
#  (0.0, 'rice'),
#  (0.0, 'semi-finished bread'),
#  (0.0, 'shopping bags'),
#  (0.0, 'skin care'),
#  (0.0, 'sliced cheese'),
#  (0.0, 'snack products'),
#  (0.0, 'softener'),
#  (0.0, 'soups'),
#  (0.0, 'spread cheese'),
#  (0.0, 'sweet spreads'),
#  (0.0, 'turkey'),
#  (0.0, 'waffles'),
#  (0.0, 'whisky'),
#  (0.0, 'artif. sweetener'),
#  (0.0, 'baby cosmetics'),
#  (0.0, 'bathroom cleaner'),
#  (0.0, 'candy'),
#  (0.0, 'cocoa drinks'),
#  (0.0, 'coffee'),
#  (0.0, 'curd cheese'),
#  (0.0, 'dish cleaner'),
#  (0.0, 'finished products'),
#  (0.0, 'frankfurter'),
#  (0.0, 'frozen fish'),
#  (0.0, 'house keeping products'),
#  (0.0, 'instant coffee'),
#  (0.0, 'liver loaf'),
#  (0.0, 'meat spreads'),
#  (0.0, 'newspapers'),
#  (0.0, 'packaged fruit/vegetables'),
#  (0.0, 'pasta'),
#  (0.0, 'popcorn'),
#  (0.0, 'pudding powder'),
#  (0.0, 'rubbing alcohol'),
#  (0.0, 'soap'),
#  (0.0, 'sparkling wine'),
#  (0.0, 'specialty bar'),
#  (0.0, 'specialty cheese'),
#  (0.0, 'specialty fat'),
#  (0.0, 'syrup'),
#  (0.0, 'vinegar'),
#  (0.0, 'white bread'),
#  (0.0, 'zwieback'),
#  (0.0, 'abrasive cleaner'),
#  (0.0, 'bags'),
#  (0.0, 'candles'),
#  (0.0, 'canned fish'),
#  (0.0, 'chewing gum'),
#  (0.0, 'citrus fruit'),
#  (0.0, 'cookware'),
#  (0.0, 'detergent'),
#  (0.0, 'flower soil/fertilizer'),
#  (0.0, 'frozen chicken'),
#  (0.0, 'hard cheese'),
#  (0.0, 'herbs'),
#  (0.0, 'jam'),
#  (0.0, 'liqueur'),
#  (0.0, 'liquor (appetizer)'),
#  (0.0, 'mustard'),
#  (0.0, 'organic sausage'),
#  (0.0, 'pot plants'),
#  (0.0, 'sausage'),
#  (0.0, 'soft cheese'),
#  (0.0, 'specialty vegetables'),
#  (0.0, 'spices'),
#  (0.0, 'tidbits'),
#  (0.0, 'beef'),
#  (0.0, 'beverages'),
#  (0.0, 'canned vegetables'),
#  (0.0, 'cat food'),
#  (0.0, 'chocolate'),
#  (0.0, 'chocolate marshmallow'),
#  (0.0, 'condensed milk'),
#  (0.0, 'dishes'),
#  (0.0, 'ham'),
#  (0.0, 'ice cream'),
#  (0.0, 'pip fruit'),
#  (0.0, 'salt'),
#  (0.0, 'salty snack'),
#  (0.0, 'sauces'),
#  (0.0, 'uht-milk'),
#  (0.0, 'cake bar'),
#  (0.0, 'cereals'),
#  (0.0, 'cooking chocolate'),
#  (0.0, 'flour'),
#  (0.0, 'kitchen towels'),
#  (0.0, 'liquor'),
#  (0.0, 'prosecco'),
#  (0.0, 'specialty chocolate'),
#  (0.0, 'bottled beer'),
#  (0.0, 'cling film/bags'),
#  (0.0, 'cream cheese '),
#  (0.0, 'curd'),
#  (0.0, 'dessert'),
#  (0.0, 'napkins'),
#  (0.0, 'sugar'),
#  (0.0, 'whipped/sour cream'),
#  (0.0, 'canned fruit'),
#  (0.0, 'dental care'),
#  (0.0, 'female sanitary products'),
#  (0.0, 'oil'),
#  (0.0, 'ready soups'),
#  (0.0, 'roll products '),
#  (0.0, 'tea'),
#  (0.0, 'butter'),
#  (0.0, 'hamburger meat'),
#  (0.0, 'long life bakery product'),
#  (0.0, 'margarine'),
#  (0.0, 'onions'),
#  (0.0, 'other vegetables'),
#  (0.0, 'chicken'),
#  (0.0, 'pickled vegetables'),
#  (0.0, 'bottled water'),
#  (0.0, 'pastry'),
#  (0.0, 'red/blush wine'),
#  (0.0, 'butter milk'),
#  (0.0, 'canned beer'),
#  (0.0, 'misc. beverages'),
#  (0.0, 'rolls/buns'),
#  (0.0, 'berries'),
#  (0.0, 'frozen meals'),
#  (0.0, 'fruit/vegetable juice'),
#  (0.0, 'pork'),
#  (0.0, 'whole milk'),
#  (0.0, 'baking powder'),
#  (0.0, 'brown bread'),
#  (0.0, 'light bulbs'),
#  (0.0, 'seasonal products')]
